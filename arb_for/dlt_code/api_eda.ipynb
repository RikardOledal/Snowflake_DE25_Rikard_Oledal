# %% [markdown]
# # EDA on jobteck API

# %%
import requests
import json


url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


if __name__ == '__main__':
    query = 'data engineer stockholm'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
# Out:
# Data Engineer - Stockholm, Kraftsam Rekrytering & Bemanning AB
# Data Engineer Stockholm Hybrid, Sway Sourcing Sweden Aktiebolag
# Data Engineer - Stockholm, Columbus Sweden AB
# Data Engineer – Konsultuppdrag, Stockholm, Liminity AB
# Data Engineer - Stockholm, Hybrid, Bumbli Group AB
# Data Engineer - Databricks to Knowit Stockholm, Knowit AB (Publ)
# Data Engineer, AcadeMedia Support AB
# Data Engineer med stark Pythonprofil - Futur pension, Friday Väst AB
# Data Engineer till innovativt techbolag, Nordicrule AB
# Data Engineer / BI Engineer till bolag inom transport och infrastruktur, Friday Väst AB
# Strategisk Data Engineer till Max Matthiessen, TNG Group AB
# Data Engineer till attraktivt konsultbolag inom Data & Analytics!, Framtiden i Sverige AB
# Data Engineer – Microsoft Fabric / Azure, Happy Group AB
# Lead Data engineer, Asta Agency AB
# Framtidssäkra din karriär - bli specialist på rekordtid!, ACADEMIC WORK SWEDEN AB
# Senior Data Engineer, Edge of Talent AB
# AI & Data Project Manager, Edge of Talent AB
# Data Engineer - Bygg framtidens dataplattformar, EdZa AB
# Data Engineer - Data Warehouse & Snowflake i AWS, AKTIEBOLAGET TRAV OCH GALOPP
# Data Engineer / BI Consultant till managementkonsultbolag, Friday Väst AB
# Data Engineer med  modern stack (Databricks, Azure Data Factory & Azure), Castra Group AB
# Senior Data Engineer, Nordic Investin Group Aktiebolag
# Senior Data Engineer to Sergel Group, Asta Agency AB
# Data Engineer, Appostrophe AB
# Senior Data Engineer, Fatalist Development AB
# Data Engineer, Strawberry Services AB
# Data Engineer, Arrowhead Game Studios AB
# Senior Data Engineer / Databricks Champion, EdZa AB
# Data Engineer, Stegra Boden AB
# Data Engineer, RebTel Networks AB
# Data Engineer, Viaplay Group Sweden AB
# Junior Data Engineer, Nextory AB
# Junior Data Engineer, Nextory AB
# Data Engineer, Celsus Engineering AB
# Data Engineer, Redeploy AB
# Data Engineer, Techrytera AB
#
# Number of hits = 36

# %%
example_search_return_number_of_hits(query)
# Out:
# Number of hits = 36

# %%
search_params = {'q': query, 'limit': 100}
json_response = _get_ads(search_params)
json_response
# Out:
# {'total': {'value': 36},
#  'positions': 41,
#  'query_time_in_millis': 7,
#  'result_time_in_millis': 44,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['data engineer'],
#   'trait': [],
#   'location': ['stockholm'],
#   'skill_must': [],
#   'occupation_must': [],
#   'trait_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'trait_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '31443496',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31443496',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590649207/logotyper/logo.png',
#    'headline': 'Data Engineer - Stockholm',
#    'application_deadline': '2026-10-30T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.\nOm företaget\nValcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.\nOm tjänsten\nSom Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.\nI rollen som Data Engineer kommer du bland annat att arbeta med:\nUtveckling och underhåll av dataplattformar i Azure\nBygga och optimera ELT-pipelines för insamling och transformering av data\nArbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt\nDatamodellering enligt stjärnmodellering och/eller medallion-arkitektur\nAutomatisering och deployment via Azure DevOps, CI/CD-pipelines\nInfrastruktur som kod med Terraform, Bicep eller ARM\nUtveckling i Python (Spark/Scala) och SQL\nIntegrationer via API:er\nVersionshantering i Git\n\nVi söker dig som\xa0\nhar minst 3 års erfarenhet som Data Engineer eller liknande roll\nHar god erfarenhet av Azure-miljön och-/eller AWS/GCP\nÄr van av att arbeta med moderna dataplattformar och datamodellering\nHar goda kunskaper i Python och SQL\nHar erfarenhet av CI/CD, Git och automatiserade deploymentflöden\nHar förståelse för hela datakedjan – från datakälla till konsumtion\n\nSom person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.\nÖVRIGT:\nAnställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.\nI denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.\nHar du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på\xa0kristina@kraftsam.se\nVi ser fram emot din ansökan!',
#     'text_formatted': '<p>Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.</p><p><strong>Om företaget</strong></p><p>Valcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.</p><p><strong>Om tjänsten</strong></p><p>Som Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.</p><p>I rollen som Data Engineer kommer du bland annat att arbeta med:</p><ul><li>Utveckling och underhåll av dataplattformar i Azure</li><li>Bygga och optimera ELT-pipelines för insamling och transformering av data</li><li>Arbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt</li><li>Datamodellering enligt stjärnmodellering och/eller medallion-arkitektur</li><li>Automatisering och deployment via Azure DevOps, CI/CD-pipelines</li><li>Infrastruktur som kod med Terraform, Bicep eller ARM</li><li>Utveckling i Python (Spark/Scala) och SQL</li><li>Integrationer via API:er</li><li>Versionshantering i Git</li></ul><p><strong>Vi söker dig som&nbsp;</strong></p><ul><li>har minst 3 års erfarenhet som Data Engineer eller liknande roll</li><li>Har god erfarenhet av Azure-miljön och-/eller AWS/GCP</li><li>Är van av att arbeta med moderna dataplattformar och datamodellering</li><li>Har goda kunskaper i Python och SQL</li><li>Har erfarenhet av CI/CD, Git och automatiserade deploymentflöden</li><li>Har förståelse för hela datakedjan – från datakälla till konsumtion</li></ul><p>Som person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.</p><p><strong>ÖVRIGT:</strong></p><p>Anställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.</p><p>I denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.</p><p>Har du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på<strong>&nbsp;</strong><strong>kristina@kraftsam.se</strong></p><p>Vi ser fram emot din ansökan!</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5590649207',
#     'name': 'Kraftsam Rekrytering & Bemanning AB',
#     'workplace': 'Bricobomba'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://pnty-apply.ponty-system.se/kraftsam?id=2134&pnty_src=platsbanken',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Stockholm',
#     'postcode': '11143',
#     'city': 'Stockholm',
#     'coordinates': [18.070462451025797, 59.33564974760078]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Stockholm',
#      'postcode': '11143',
#      'city': 'Stockholm',
#      'coordinates': [18.070462451025797, 59.33564974760078]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Kristina Maksimovic',
#      'description': None,
#      'email': 'kristina@kraftsam.se',
#      'telephone': None,
#      'contact_type': 'Rekryterare'}],
#    'publication_date': '2026-09-07T08:36:21',
#    'last_publication_date': '2026-10-30T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1788762981859},
#   {'relevance': 1.0,
#    'id': '31117617',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31117617',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5593607517/logotyper/logo.png',
#    'headline': 'Data Engineer Stockholm Hybrid',
#    'application_deadline': '2026-11-28T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Om uppdraget 🚀\nVi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.\nI rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.\nHär värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.\nDina arbetsuppgifter 💻\nDesigna, utveckla och underhålla skalbara datapipelines\n\n\nBygga och vidareutveckla moderna dataplattformar\n\n\nSäkerställa hög datakvalitet, säkerhet och förvaltningsbarhet\n\n\nArbeta med Python, SQL och moderna dataverktyg\n\n\nImplementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar\n\n\nOmvandla verksamhetsbehov till robusta tekniska lösningar\n\n\nDelta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet\n\n\nUtforska och använda AI-verktyg för att effektivisera utvecklingsarbetet\n\nFörväntade leveranser 🎯\nSkalbara och robusta datapipelines\n\n\nDataplattformar med hög kvalitet och säkerhet\n\n\nVälstrukturerade dataflöden som stödjer verksamhetens behov\n\n\nHållbara tekniska lösningar med lång livslängd\n\n\nDokumenterad och förvaltningsbar kod\n\n\nAktivt bidrag till teknisk utveckling och kunskapsdelning\n\nDin profil ✅Obligatoriska kompetenser\nUniversitetsexamen inom teknik, datavetenskap eller motsvarande\n\n\nMinst 4–5 års erfarenhet som Data Engineer eller Backend Developer\n\n\nMycket goda kunskaper i Python\n\n\nMycket goda kunskaper i SQL\n\n\nErfarenhet av att utveckla och underhålla datapipelines\n\n\nErfarenhet av moderna dataplattformar\n\n\nFlytande svenska i tal och skrift\n\n\nFörmåga att arbeta hands-on i tekniska leveranser\n\nMeriterande färdigheter ⭐\nErfarenhet av Databricks\n\n\nErfarenhet av Microsoft Fabric\n\n\nErfarenhet av Apache Spark\n\n\nErfarenhet av dbt\n\n\nErfarenhet av Azure, AWS eller GCP\n\n\nErfarenhet av ETL- och ELT-processer\n\n\nErfarenhet av AI-verktyg och moderna utvecklingsverktyg\n\n\nKonsulterfarenhet\n\nPersonliga egenskaper 🤝\nVi tror att du är en person som:\n\nHar ett starkt kvalitetsfokus\n\n\nÄr tekniskt nyfiken och gillar att lära dig nytt\n\n\nKan kommunicera tekniska lösningar på ett tydligt sätt\n\n\nTrivs i samarbete med både kollegor och verksamhet\n\n\nHar förståelse för sambandet mellan teknik och affärsnytta\n\n\nÄr prestigelös och delar gärna med dig av din kunskap\n\nVi erbjuder 🎁\nFast månadslön\n\n\nSjukvårdsförsäkring\n\n\nPensionsavsättning\n\n\nFriskvårdsbidrag\n\n\nUtökad föräldrapenning\n\n\nMöjlighet att påverka din egen utveckling\n\n\nLångsiktiga och tekniskt intressanta uppdrag\n\n\nEn kultur präglad av samarbete, lärande och kvalitet\n\n\n📍 Plats: Stockholm (Hybrid)\n⏰ Omfattning: Heltid\n📅 Start: Omgående\n📌 Sista ansökningsdag: Urval sker löpande\nSway Sourcing är en innovativ rekryteringspartner som specialiserar sig på att matcha rätt talang med rätt företag – snabbt och effektivt. Vårt huvudfokus ligger inom Ekonomi, Administration, HR, Marknad och IT, men vi har även den breda expertis och flexibilitet som krävs för att leverera skräddarsydda rekryteringslösningar inom alla branscher.\nTrots att vi är en relativt ny aktör har vi redan byggt förtroende hos många av Sveriges största företag och arbetar både nationellt och internationellt. Med baser i Sverige och Spanien erbjuder vi en unik kombination av lokal expertis och global räckvidd. Vårt starka nätverk och djupa branschinsikter gör oss till en självklar partner för företag som vill ligga steget före i sin rekrytering.',
#     'text_formatted': '<strong>Om uppdraget 🚀</strong><p>Vi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.</p><p>I rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.</p><p>Här värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.</p><strong>Dina arbetsuppgifter 💻</strong><ul><li><p>Designa, utveckla och underhålla skalbara datapipelines</p></li><li><p>Bygga och vidareutveckla moderna dataplattformar</p></li><li><p>Säkerställa hög datakvalitet, säkerhet och förvaltningsbarhet</p></li><li><p>Arbeta med Python, SQL och moderna dataverktyg</p></li><li><p>Implementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar</p></li><li><p>Omvandla verksamhetsbehov till robusta tekniska lösningar</p></li><li><p>Delta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet</p></li><li><p>Utforska och använda AI-verktyg för att effektivisera utvecklingsarbetet</p></li></ul><strong>Förväntade leveranser 🎯</strong><ul><li><p>Skalbara och robusta datapipelines</p></li><li><p>Dataplattformar med hög kvalitet och säkerhet</p></li><li><p>Välstrukturerade dataflöden som stödjer verksamhetens behov</p></li><li><p>Hållbara tekniska lösningar med lång livslängd</p></li><li><p>Dokumenterad och förvaltningsbar kod</p></li><li><p>Aktivt bidrag till teknisk utveckling och kunskapsdelning</p></li></ul><strong>Din profil ✅</strong><strong>Obligatoriska kompetenser</strong><ul><li><p>Universitetsexamen inom teknik, datavetenskap eller motsvarande</p></li><li><p>Minst 4–5 års erfarenhet som Data Engineer eller Backend Developer</p></li><li><p>Mycket goda kunskaper i Python</p></li><li><p>Mycket goda kunskaper i SQL</p></li><li><p>Erfarenhet av att utveckla och underhålla datapipelines</p></li><li><p>Erfarenhet av moderna dataplattformar</p></li><li><p>Flytande svenska i tal och skrift</p></li><li><p>Förmåga att arbeta hands-on i tekniska leveranser</p></li></ul><strong>Meriterande färdigheter ⭐</strong><ul><li><p>Erfarenhet av Databricks</p></li><li><p>Erfarenhet av Microsoft Fabric</p></li><li><p>Erfarenhet av Apache Spark</p></li><li><p>Erfarenhet av dbt</p></li><li><p>Erfarenhet av Azure, AWS eller GCP</p></li><li><p>Erfarenhet av ETL- och ELT-processer</p></li><li><p>Erfarenhet av AI-verktyg och moderna utvecklingsverktyg</p></li><li><p>Konsulterfarenhet</p></li></ul><strong>Personliga egenskaper 🤝</strong><p>Vi tror att du är en person som:</p><ul><li><p>Har ett starkt kvalitetsfokus</p></li><li><p>Är tekniskt nyfiken och gillar att lära dig nytt</p></li><li><p>Kan kommunicera tekniska lösningar på ett tydligt sätt</p></li><li><p>Trivs i samarbete med både kollegor och verksamhet</p></li><li><p>Har förståelse för sambandet mellan teknik och affärsnytta</p></li><li><p>Är prestigelös och delar gärna med dig av din kunskap</p></li></ul><strong>Vi erbjuder 🎁</strong><ul><li><p>Fast månadslön</p></li><li><p>Sjukvårdsförsäkring</p></li><li><p>Pensionsavsättning</p></li><li><p>Friskvårdsbidrag</p></li><li><p>Utökad föräldrapenning</p></li><li><p>Möjlighet att påverka din egen utveckling</p></li><li><p>Långsiktiga och tekniskt intressanta uppdrag</p></li><li><p>En kultur präglad av samarbete, lärande och kvalitet</p></li></ul><p><strong>📍 Plats:</strong> Stockholm (Hybrid)</p><p><strong>⏰ Omfattning:</strong> Heltid</p><p><strong>📅 Start:</strong> Omgående</p><p><strong>📌 Sista ansökningsdag:</strong> Urval sker löpande</p><p>Sway Sourcing är en innovativ rekryteringspartner som specialiserar ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.swaysourcing.com',
#     'organization_number': '5593607517',
#     'name': 'Sway Sourcing Sweden Aktiebolag',
#     'workplace': 'Sway Sourcing'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7828036-2028375',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.swaysourcing.com/jobs/7828036-data-engineer-stockholm-hybrid/applications/new?promotion=2028375-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'fg7B_yov_smw',
#     'label': 'Systemutvecklare/Programmerare',
#     'legacy_ams_taxonomy_id': '2419'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': '111 29',
#     'postcode': '11129',
#     'city': 'Stockholm',
#     'coordinates': [18.071134441016927, 59.324378835098074]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': '111 29',
#      'postcode': '11129',
#      'city': 'Stockholm',
#      'coordinates': [18.071134441016927, 59.324378835098074]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-06-01T13:24:58',
#    'last_publication_date': '2026-11-28T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1780313098640},
#   {'relevance': 1.0,
#    'id': '30990931',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30990931',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5568177124/logotyper/logo.png',
#    'headline': 'Data Engineer - Stockholm',
#    'application_deadline': '2026-10-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Arbetsuppgifter\n\nSom Data Engineer på Columbus kommer du att vara en del av ett team som levererar moderna Data & AI-lösningar till kunder inom olika branscher. Din roll fokuserar på att bygga skalbara och moderna dataplattformar – vilket möjliggör för avancerad analys\xa0till beslutsstöd.\nEn typisk arbetsdag kan innebära att du designar och bygger datapipelines i Azure Data Factory, arbetar med Datalake-arkitekturer i Microsoft Fabric eller utvecklar lösningar i plattformar som Databricks eller Snowflake. Du samarbetar med lösningsarkitekter och affärskonsulter för att leverera värdefulla lösningar för våra kunder.\nVi arbetar främst inom Microsofts teknologistack, och dina projekt kommer ofta att involvera tjänster som Azure Data Lake, Synapse Analytics, Power BI med mera. Erfarenhet av – eller nyfikenhet på – Microsoft Fabric är mycket meriterande, då många av våra kunder är på väg i den riktningen.\n\nSå här säger Kristin – Senior BI-konsult – om livet på Columbus: "En stor anledning till att jag började på Columbus var möjligheten att få arbeta både med projektleveranser och ny teknik. Jag uppskattar att vara en del av ett team som driver lösningar framåt tillsammans. Vi känner varandra väl och delar på ansvar och erfarenheter, vilket gör att vi snabbt kan anpassa oss och nå våra mål. Att arbeta med flera kunder samtidigt ger mig både trygghet inom de områden där jag är stark och möjligheten att växa genom nya utmaningar. För mig handlar projektleveranser om att skapa långsiktigt värde och hållbara lösningar som verkligen gör skillnad för kunden."\n\nVad vi önskar att du har med dig\nDu har ett par års praktisk erfarenhet av att bygga datapipelines och hantera dataflöden i molnmiljöer, gärna i Azure.\n\n\nDu är van att arbeta med både strukturerad och ostrukturerad data och har god förståelse för moderna data warehouse-koncept.\n\n\nDu har lätt för att samarbeta med både tekniska team och kundens\xa0representanter\n\n\nPlease note that this position requires fluency in English & Swedish and requires a Swedish working VISA/Citizenship.\nAnsökan och nästa steg\nHos oss ansöker du enkelt\xa0med din LinkedIn-profil eller CV, utan att behöva fylla i långa frågeformulär. Du behöver inte skicka in något personligt brev.\xa0\nI vår rekryteringsprocess använder vi logik- och personlighetstester. Vi tar alltid referenser och genomför en bakgrundskontroll innan anställning eller erbjudande ges. Intervjuer sker löpande.\xa0Vid frågor är du välkommen att kontakta ansvarig rekryterare Daniel Sparrow.\xa0\nOm Data & AI\nVilka är vi? Vi är ett team med BI-konsulter som levererar Data- och AI-projekt inom Business Intelligence, AI och Machine Learning. Vi samarbetar nära med konsulter från andra affärsområden – Dynamics, M3 och Digital Commerce.\nVarför? Vi vill hjälpa våra kunder att nå sina affärsmål och göra deras vardag mer effektiv! Målet är att säkerställa deras långsiktiga framgång och guida kunderna genom att vara deras Trusted Advisor. Vi samarbetar med kunderna för att optimera deras lösningar. 💫 \nJobba på Columbus\nColumbus är ett företag där värderingar står i centrum, där engagerade medarbetare stöttar varandra genom både toppar och dalar. Vi tror på balans mellan jobb och fritid – oavsett om det handlar om att lämna på förskola\xa0eller att ta emot ett paket "någon gång mellan 10 och 19".\xa0Hos oss finns tid för återhämtning, och vi arbetar proaktivt med fokus på framtiden. Vi vet också hur man firar framgångar, med allt från fika och lyxiga frukostar till after work på kontoret, och gör det gärna ofta!\xa0🥳 \nStay curious, Build trust, Collaborate, Deliver customer success - Vi vill hävda att våra värdeord gör mer nytta än att bara hänga snyggt på väggen! Dessa vägleder vårt arbete både internt och externt. Genom långsiktiga partnerskap med våra kunder, interna initiativ med Culture Ambassadors, kompetensutveckling inom affärsområdena till högkvalitativa lösningar till våra kunder.  \nVad an ...
#     'text_formatted': '<strong>Arbetsuppgifter</strong><p></p><p>Som Data Engineer på Columbus kommer du att vara en del av ett team som levererar moderna Data &amp; AI-lösningar till kunder inom olika branscher. Din roll fokuserar på att bygga skalbara och moderna dataplattformar – vilket möjliggör för avancerad analys\xa0till beslutsstöd.</p><p>En typisk arbetsdag kan innebära att du designar och bygger datapipelines i Azure Data Factory, arbetar med Datalake-arkitekturer i Microsoft Fabric eller utvecklar lösningar i plattformar som Databricks eller Snowflake. Du samarbetar med lösningsarkitekter och affärskonsulter för att leverera värdefulla lösningar för våra kunder.</p><p>Vi arbetar främst inom Microsofts teknologistack, och dina projekt kommer ofta att involvera tjänster som Azure Data Lake, Synapse Analytics, Power BI med mera. Erfarenhet av – eller nyfikenhet på – Microsoft Fabric är mycket meriterande, då många av våra kunder är på väg i den riktningen.</p><p></p><p><strong>Så här säger Kristin – Senior BI-konsult – om livet på Columbus:</strong> "En stor anledning till att jag började på Columbus var möjligheten att få arbeta både med projektleveranser och ny teknik. Jag uppskattar att vara en del av ett team som driver lösningar framåt tillsammans. Vi känner varandra väl och delar på ansvar och erfarenheter, vilket gör att vi snabbt kan anpassa oss och nå våra mål. Att arbeta med flera kunder samtidigt ger mig både trygghet inom de områden där jag är stark och möjligheten att växa genom nya utmaningar. För mig handlar projektleveranser om att skapa långsiktigt värde och hållbara lösningar som verkligen gör skillnad för kunden."</p><p></p><strong>Vad vi önskar att du har med dig</strong><ul><li><p>Du har ett par års praktisk erfarenhet av att bygga datapipelines och hantera dataflöden i molnmiljöer, gärna i Azure.</p></li><li><p>Du är van att arbeta med både strukturerad och ostrukturerad data och har god förståelse för moderna data warehouse-koncept.</p></li><li><p>Du har lätt för att samarbeta med både tekniska team och kundens\xa0representanter</p></li></ul><p><strong><em>Please note that this position requires fluency in English &amp; Swedish and requires a Swedish working VISA/Citizenship.</em></strong></p><strong>Ansökan och nästa steg</strong><p>Hos oss ansöker du enkelt\xa0med din LinkedIn-profil eller CV, utan att behöva fylla i långa frågeformulär. Du behöver inte skicka in något personligt brev.\xa0</p><p>I vår rekryteringsprocess använder vi logik- och personlighetstester. Vi tar alltid referenser och genomför en bakgrundskontroll innan anställning eller erbjudande ges. Intervjuer sker löpande.\xa0Vid frågor är du välkommen att kontakta ansvarig rekryterare Daniel Sparrow.\xa0</p><strong>Om Data &amp; AI</strong><p><strong>Vilka är vi? </strong>Vi är ett team med BI-konsulter som levererar Data- och AI-projekt inom Business Intelligence, AI och Machine Learning. Vi samarbetar nära med konsulter från andra affärsområden – Dynamics, M3 och Digital Commerce.</p><p><strong>Varför? </strong>Vi vill hjälpa våra kunder att nå sina affärsmål och göra deras vardag mer effektiv! Målet är att säkerställa deras långsiktiga framgång och guida kunderna genom att vara deras<em> Trusted Advisor</em>. Vi samarbetar med kunderna för att optimera deras lösningar. 💫<strong> </strong></p><strong>Jobba på Columbus</strong><p>Columbus är ett företag där värderingar står i centrum, där engagerade medarbetare stöttar varandra genom både toppar och dalar. Vi tror på balans mellan jobb och fritid – oavsett om det handlar om att lämna på förskola\xa0eller att ta emot ett paket "någon gång mellan 10 och 19".\xa0Hos oss finns tid för återhämtning, och vi arbetar proaktivt med fokus på framtiden. Vi vet också hur man firar framgångar, med allt från fika och lyxiga frukostar till after work på kontoret, och gör det gärna ofta!\xa0🥳 </p><p><strong>Stay curious, Build trust, Collaborate, Deliver customer success</strong> - Vi vill hävda ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'asrX_9Df_ukn',
#     'label': 'Fast och rörlig lön',
#     'legacy_ams_taxonomy_id': '7'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://career.columbusglobal.com',
#     'organization_number': '5568177124',
#     'name': 'Columbus Sweden AB',
#     'workplace': 'Columbus Sweden, Poland, Germany & Czech Republic'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7615684-1979836',
#     'email': None,
#     'via_af': False,
#     'url': 'https://career.columbusglobal.com/jobs/7615684-data-engineer-stockholm/applications/new?promotion=1979836-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'TT8h_qKk_1iu',
#     'label': 'Affärskonsult, IT',
#     'legacy_ams_taxonomy_id': '7579'},
#    'occupation_group': {'concept_id': 'UXKZ_3zZ_ipB',
#     'label': 'Systemanalytiker och IT-arkitekter m.fl.',
#     'legacy_ams_taxonomy_id': '2511'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Drottninggatan 71D',
#     'postcode': '11136',
#     'city': 'Stockholm',
#     'coordinates': [18.0586425696733, 59.3365331584778]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Drottninggatan 71D',
#      'postcode': '11136',
#      'city': 'Stockholm',
#      'coordinates': [18.0586425696733, 59.3365331584778]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-05-04T15:46:48',
#    'last_publication_date': '2026-10-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1777902408632},
#   {'relevance': 0.9566538174996003,
#    'id': '30859146',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30859146',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590917851/logotyper/logo.png',
#    'headline': 'Data Engineer – Konsultuppdrag, Stockholm',
#    'application_deadline': '2026-09-29T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Om uppdraget\nVi förbereder just nu ett spännande konsultuppdrag där du som Data Engineer får möjlighet att ta ett helhetsgrepp kring en organisations datalandskap. Uppdraget handlar i grunden om att se till att rätt data når rätt personer i rätt tid – och att infrastrukturen bakom är robust, skalbar och väldokumenterad.\nDu kommer att arbeta i skärningspunkten mellan teknik och verksamhet: bygga och förfina datapipelines, ta fram beslutsunderlag genom visualisering, och vara den person teamet vänder sig till när det blir tekniskt komplext. Det här passar dig som trivs med att äga helheten snarare än att bara leverera enskilda komponenter.\nPlats: Stockholm (hybrid, 2–3 dagar på plats per vecka)  Start: Omgående  Omfattning: Heltid \n Det här jobbar du med i praktiken\nBygga, drifta och finjustera ett Snowflake-baserat datalager\n\n\nSkapa och vidareutveckla rapporter och dashboards i Power BI som verksamheten faktiskt använder\n\n\nDesigna och underhålla datapipelines med ETL/ELT-metoder\n\n\nKvalitetssäkra data och se till att hanteringen lever upp till GDPR och interna riktlinjer\n\n\nHålla dokumentationen levande – datamodeller, flöden och rapportlogik\n\n\nVara bryggan mellan IT-avdelning och affärssida\n\n\nCoacha och stötta kollegor i tekniska frågor\n\nDin profil\nDu har en stark teknisk grund och är van att jobba hands-on med data i hela kedjan – från källa till färdig rapport. Vi ser gärna att du har erfarenhet av:\n\nSnowflake – du har jobbat aktivt med plattformen, inte bara snuddat vid den\n\n\nPower BI – du bygger genomtänkta rapporter och förstår datamodellen bakom\n\n\nSQL – ditt starkaste verktyg i verktygslådan\n\n\nPython – för automation, transformation eller analys\n\n\nETL/ELT-verktyg – gärna dbt, men annan relevant erfarenhet fungerar också\n\n\nDu kommunicerar obehindrat på svenska och engelska och är den typen som tar initiativ, driver framåt och inte väntar på att bli tillsagd.\nBonuspoäng om du även har:\nErfarenhet av agilt arbetssätt och DevOps-tänk inom dataområdet\n\n\nPraktisk erfarenhet av datamodellering och prestandaoptimering i datalager\n\nLåter det som du?\nHör av dig med ditt CV så berättar vi mer. Uppdraget startar omgående och vi vill gärna ha dialog med relevanta kandidater så snart som möjligt.',
#     'text_formatted': '<strong>Om uppdraget</strong><p>Vi förbereder just nu ett spännande konsultuppdrag där du som Data Engineer får möjlighet att ta ett helhetsgrepp kring en organisations datalandskap. Uppdraget handlar i grunden om att se till att rätt data når rätt personer i rätt tid – och att infrastrukturen bakom är robust, skalbar och väldokumenterad.</p><p>Du kommer att arbeta i skärningspunkten mellan teknik och verksamhet: bygga och förfina datapipelines, ta fram beslutsunderlag genom visualisering, och vara den person teamet vänder sig till när det blir tekniskt komplext. Det här passar dig som trivs med att äga helheten snarare än att bara leverera enskilda komponenter.</p><p><strong>Plats:</strong> Stockholm (hybrid, 2–3 dagar på plats per vecka)  <strong>Start:</strong> Omgående  <strong>Omfattning:</strong> Heltid </p><strong> Det här jobbar du med i praktiken</strong><ul><li><p>Bygga, drifta och finjustera ett Snowflake-baserat datalager</p></li><li><p>Skapa och vidareutveckla rapporter och dashboards i Power BI som verksamheten faktiskt använder</p></li><li><p>Designa och underhålla datapipelines med ETL/ELT-metoder</p></li><li><p>Kvalitetssäkra data och se till att hanteringen lever upp till GDPR och interna riktlinjer</p></li><li><p>Hålla dokumentationen levande – datamodeller, flöden och rapportlogik</p></li><li><p>Vara bryggan mellan IT-avdelning och affärssida</p></li><li><p>Coacha och stötta kollegor i tekniska frågor</p></li></ul><strong>Din profil</strong><p>Du har en stark teknisk grund och är van att jobba hands-on med data i hela kedjan – från källa till färdig rapport. Vi ser gärna att du har erfarenhet av:</p><ul><li><p><strong>Snowflake</strong> – du har jobbat aktivt med plattformen, inte bara snuddat vid den</p></li><li><p><strong>Power BI</strong> – du bygger genomtänkta rapporter och förstår datamodellen bakom</p></li><li><p><strong>SQL</strong> – ditt starkaste verktyg i verktygslådan</p></li><li><p><strong>Python</strong> – för automation, transformation eller analys</p></li><li><p><strong>ETL/ELT-verktyg</strong> – gärna dbt, men annan relevant erfarenhet fungerar också</p></li></ul><p>Du kommunicerar obehindrat på <strong>svenska och engelska</strong> och är den typen som tar initiativ, driver framåt och inte väntar på att bli tillsagd.</p><strong><strong>Bonuspoäng om du även har:</strong></strong><ul><li><p>Erfarenhet av agilt arbetssätt och DevOps-tänk inom dataområdet</p></li><li><p>Praktisk erfarenhet av datamodellering och prestandaoptimering i datalager</p></li></ul><strong>Låter det som du?</strong><p>Hör av dig med ditt CV så berättar vi mer. Uppdraget startar omgående och vi vill gärna ha dialog med relevanta kandidater så snart som möjligt.</p><p></p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://jobb.liminity.se',
#     'organization_number': '5590917851',
#     'name': 'Liminity AB',
#     'workplace': 'Liminity AB'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7508091-1927705',
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobb.liminity.se/jobs/7508091-data-engineer-konsultuppdrag-stockholm/applications/new?promotion=1927705-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Kungsholmsgatan 13A',
#     'postcode': '11227',
#     'city': 'Stockholm',
#     'coordinates': [18.048279652214, 59.3309166785629]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Kungsholmsgatan 13A',
#      'postcode': '11227',
#      'city': 'Stockholm',
#      'coordinates': [18.048279652214, 59.3309166785629]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-04-02T11:57:42',
#    'last_publication_date': '2026-09-29T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1775123862035},
#   {'relevance': 0.94911322649824,
#    'id': '31479661',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31479661',
#    'logo_url': None,
#    'headline': 'Data Engineer - Stockholm, Hybrid',
#    'application_deadline': '2026-10-15T23:59:59',
#    'number_of_vacancies': 2,
#    'description': {'text': "Company Description:\nThe Employer is a modern data consultancy Company focused on building long-term, high-quality data solutions that create real business value. In a world where AI can generate code in seconds, we believe that true impact comes from deep craftsmanship, strong data modeling, and a solid understanding of quality and security.\nWe are founded by experienced entrepreneurs, technical leaders, and sales professionals who know how to build sustainable teams and meaningful client partnerships. Our ambition is to shape the future of tech consulting by combining technical excellence with a human-centered culture.\n\n\nOur services / Product:\nWe design and build robust data platforms, pipelines, and architectures that enable organizations to turn data into actionable insights.\nOur work spans across modern data ecosystems, including cloud-based platforms, advanced data processing, and AI-supported workflows. We focus on scalable, maintainable, and secure solutions using technologies such as Python, SQL, Microsoft Fabric, Databricks, Apache Spark, and dbt.\n\n\nAbout us & our references:\nWe work closely with our clients to understand their real needs and deliver solutions that stand the test of time. Rather than chasing short-term projects, we focus on long-term value creation and strong partnerships.\nOur founders bring extensive experience from building successful companies and leading high-performing teams, ensuring that both our consultants and our clients are set up for success.\n\n\nOur team & Culture:\nWe believe that great technology is built by people who care.\nWe foster a culture where knowledge sharing is as natural as grabbing a coffee together. There is no room for unnecessary internal competition or sharp elbows. Instead, we focus on collaboration, curiosity, and continuous learning.\nYou will join a team that values both technical excellence and human connection, proving that the best tech companies can be both smart and kind.\n\n\nRequirement Profile:\nWe are looking for a Data Engineer with 5+ years of experience as a developer or in a related field, including minimum 3 years of Data Engineering, who wants to grow within the data domain and work with modern technologies in a meaningful way. You take ownership of the business understanding and of the customer project and relationship, making sure the technical work connects to real value for the client.\n\n\nJob Responsibilities:\n- Design, build, and maintain scalable data pipelines and data platforms\n- Ensure high data quality, security, and maintainability across solutions\n- Collaborate with clients to translate business needs into robust technical solutions\n- Act as a bridge between modern technologies and sustainable system design\n\n\nDaily Activities:\nYou work at assignments at our client's site.\n- Develop and optimize data pipelines using tools such as Python, SQL, and modern data platforms\n- Work with cloud and data processing technologies like Databricks, Microsoft Fabric, Spark, or dbt\n- Participate in client projects where you ensure long-term value and technical excellence\n- Explore and apply AI tools to enhance development workflows while maintaining high standards\n\n\nQualifications and Requirements:\n- A university degree in engineering, computer science, or a related field\n- 5+ years as a developer, with minimum 3 years in Data Engineering\n- Strong skills in Python and SQL\n- Experience with building data pipelines and working with modern data platforms\n- Familiarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus\n- Interest in AI and modern coding tools such as coding agents\n- Fluent in Swedish, both spoken and written.\n\n\nPersonal Attributes:\n- Quality-oriented mindset with a strong understanding that data quality is the foundation of all analytics and AI\n- Technically curious with a broad interest in data, systems, and new technologies\n- Able to critica ...
# ...
#     'text_formatted': '<p>TL;DR</p><p>→ You own the data layer, ingestion, transformation, and modeling that makes analytics, reporting and AI possible.</p><p>→ Consultant role across the Nordics, with clients spanning industries from financial services to manufacturing.</p><p>→ You work in cross functional delivery teams alongside Platform, Analytics and GenAI Developers, each owning a distinct layer of the stack.</p><p>→ Certifications without a debate. Colleagues who are obsessed with the craft. Freedom to grow your way.</p><p><br></p><p><strong>What you\'ll do</strong></p><p>As a Data Engineer, you’ll be building the data platforms that everything else depends on. From raw source systems to production-ready models consumed by analysts, ML pipelines, and business users. You own the path data takes to become useful. The work is hands-on Python and SQL, heavy on PySpark, and grounded in Kimball modeling and lakehouse architecture.</p><p>You come in before the solution is defined. Together with the client, you shape what gets built, then you build it. You\'ll work in cross-functional delivery teams alongside platform engineers and AI developers, each owning a distinct layer of the stack.</p><p><br></p><p>A few examples of what this looks like in practice:</p><ul><li>Building a Kafka-based ingestion framework for a major insurance group, onboarding several thousand tables at scale so multiple downstream teams can actually use the data they need.</li></ul><p><br></p><ul><li>Lifting an on-prem data warehouse into a cloud-based Databricks lakehouse for a Nordic logistics company, standing up CI/CD, integration, modeling, and quality assurance, then scaling for new use cases.</li></ul><p><br></p><ul><li>Auditing a manufacturing company\'s data platform against best practices, delivering a migration plan, then staying on to bring in new sources, optimize workflows, and build out analytics models.</li></ul><p><br></p><p>The bar for what "done" means here is high: production-grade, observable, secure and used.</p><p><br></p><p><strong>What you get</strong></p><p><strong>Assignments that accelerate you.</strong> Every 6–18 months you\'re in a new engagement. New industry, new architecture decisions, new stakeholders to earn trust from. You\'ll face more distinct technical challenges in two years here than most engineers see in five.</p><p><strong>Work that\'s hard to come by elsewhere.</strong> Modern data platforms underpinning enterprise AI is one of the most technically demanding spaces right now. The problems here aren\'t solved yet, and you\'ll be among the people solving them.</p><p><strong>Your direction, your call.</strong> Want to go deep technically, specialise in Databricks and Spark engineering, platform foundations or analytics engineering? Go for it. Want to grow toward Tech Lead or Solution Architect, steering delivery and building long-term client relationships? Also go for it. Both paths are real and equally valued.</p><p><strong>People who make you better.</strong> The people here are genuinely passionate about technology, not as a job, but as something they care about. Engineers who go deep because they want to, follow the space obsessively, and get restless when things stop moving. That\'s what keeps Redeploy consistently ahead, and it\'s what you\'ll feel from day one.</p><p><strong>The Perks.</strong> 30 days vacation · hybrid work and flexible hours · private medical insurance · pension (ITP1) · wellness allowance 5,000 SEK · free choice of tools and tech · free breakfast, soda and snacks · yearly gatherings and AW\'s · a team with genuine interests outside work — gaming, food, running, padel, golf, football, cycling</p><p><br></p><p><strong>Who you are</strong></p><p>You take ownership, hold yourself to a high standard, and bring real opinions to the table. You communicate clearly with both technical and non-technical stakeholders, and you\'re energised by the consulting pace, new challenges, new contexts, and t ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#     'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'asrX_9Df_ukn',
#     'label': 'Fast och rörlig lön',
#     'legacy_ams_taxonomy_id': '7'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'http://redeploy.com',
#     'organization_number': '5590055280',
#     'name': 'Redeploy AB',
#     'workplace': 'Redeploy AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://careers.redeploy.com/jobs/5095583-data-engineer',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Torsgatan 4',
#     'postcode': '11361',
#     'city': 'Stockholm',
#     'coordinates': [18.044506816056344, 59.338577169215036]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Torsgatan 4',
#      'postcode': '11361',
#      'city': 'Stockholm',
#      'coordinates': [18.044506816056344, 59.338577169215036]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-04-20T10:45:10',
#    'last_publication_date': '2026-09-30T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1777556480755},
#   {'relevance': 0.47220161127348514,
#    'id': '30862433',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30862433',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-09-29T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'About us At Techrytera AB, recruitment starts with you. We are a staffing and recruitment company with deep expertise and a clear focus on IT and Engineering. With our industry knowledge and close dialogue with both candidates and clients, we create precise matches where the right skills meet the right needs.\nWe believe that a truly great match is not just about a job description – it’s about your experience, your potential, and what you genuinely want to develop in. That’s why we always focus on the individual. By understanding your background, motivations, and ambitions, we can connect you with assignments and roles at our clients where you have the right conditions to grow and make an impact.\nOur goal is to build long-term and meaningful collaborations – for both you as a candidate and for our clients. \nJob Description We are looking for a Data Engineer or Backend Developer with a 4-5 years of experience or more senior who wants to grow within the data domain and work with modern technologies in a meaningful way.\nQualifications and Requirements:\nA degree in engineering, computer science, or a related field\n4-5 years of experience or more as a Data Engineer or Backend Developer\nStrong skills in Python and SQL\nExperience with building data pipelines and working with modern data platforms\nFamiliarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus\nInterest in AI and modern coding tools such as coding agents\nFluent in Swedish, both spoken and written.\nApplication\nWhen you apply through Techrytera AB, you’re not just applying for a job – you’re starting a dialogue about your career path. We want to get to know you, your experience, and your ambitions so that we can match you with the right opportunities at our clients.\nDoes this sound interesting? Submit your application or get in touch with us to learn more. We look forward to discovering the next step in your career together with you.',
#     'text_formatted': '<p><strong>About us</strong> At <strong>Techrytera AB</strong>, recruitment starts with you. We are a staffing and recruitment company with deep expertise and a clear focus on IT and Engineering. With our industry knowledge and close dialogue with both candidates and clients, we create precise matches where the right skills meet the right needs.</p><p>We believe that a truly great match is not just about a job description – it’s about your experience, your potential, and what you genuinely want to develop in. That’s why we always focus on the individual. By understanding your background, motivations, and ambitions, we can connect you with assignments and roles at our clients where you have the right conditions to grow and make an impact.</p><p>Our goal is to build long-term and meaningful collaborations – for both you as a candidate and for our clients. </p><p><strong>Job Description</strong> We are looking for a Data Engineer or Backend Developer with a 4-5 years of experience or more senior who wants to grow within the data domain and work with modern technologies in a meaningful way.</p><p><strong>Qualifications and Requirements:</strong></p><p>A degree in engineering, computer science, or a related field</p><p>4-5 years of experience or more as a Data Engineer or Backend Developer</p><p>Strong skills in Python and SQL</p><p>Experience with building data pipelines and working with modern data platforms</p><p>Familiarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus</p><p>Interest in AI and modern coding tools such as coding agents</p><p>Fluent in Swedish, both spoken and written.</p><p><strong>Application</strong></p><p>When you apply through <strong>Techrytera AB</strong>, you’re not just applying for a job – you’re starting a dialogue about your career path. We want to get to know you, your experience, and your ambitions so that we can match you with the right opportunities at our clients.</p><p>Does this sound interesting? Submit your application or get in touch with us to learn more. We look forward to discovering the next step in your career together with you.</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.techrytera.se',
#     'organization_number': '5595683623',
#     'name': 'Techrytera AB',
#     'workplace': 'Techrytera AB'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7511135-1928800',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.techrytera.se/jobs/7511135-data-engineer/applications/new?promotion=1928800-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Sveavägen 137',
#     'postcode': '11346',
#     'city': 'Stockholm',
#     'coordinates': [18.0503914327707, 59.3491119760471]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Sveavägen 137',
#      'postcode': '11346',
#      'city': 'Stockholm',
#      'coordinates': [18.0503914327707, 59.3491119760471]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-04-02T16:34:47',
#    'last_publication_date': '2026-09-29T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1775140487436}]}

# %%
json_response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
json_response.get('result_time_in_millis')
# Out:
# 44

# %%
json_response.get("hits")
# Out:
# [{'relevance': 1.0,
#   'id': '31443496',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31443496',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590649207/logotyper/logo.png',
#   'headline': 'Data Engineer - Stockholm',
#   'application_deadline': '2026-10-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.\nOm företaget\nValcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.\nOm tjänsten\nSom Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.\nI rollen som Data Engineer kommer du bland annat att arbeta med:\nUtveckling och underhåll av dataplattformar i Azure\nBygga och optimera ELT-pipelines för insamling och transformering av data\nArbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt\nDatamodellering enligt stjärnmodellering och/eller medallion-arkitektur\nAutomatisering och deployment via Azure DevOps, CI/CD-pipelines\nInfrastruktur som kod med Terraform, Bicep eller ARM\nUtveckling i Python (Spark/Scala) och SQL\nIntegrationer via API:er\nVersionshantering i Git\n\nVi söker dig som\xa0\nhar minst 3 års erfarenhet som Data Engineer eller liknande roll\nHar god erfarenhet av Azure-miljön och-/eller AWS/GCP\nÄr van av att arbeta med moderna dataplattformar och datamodellering\nHar goda kunskaper i Python och SQL\nHar erfarenhet av CI/CD, Git och automatiserade deploymentflöden\nHar förståelse för hela datakedjan – från datakälla till konsumtion\n\nSom person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.\nÖVRIGT:\nAnställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.\nI denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.\nHar du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på\xa0kristina@kraftsam.se\nVi ser fram emot din ansökan!',
#    'text_formatted': '<p>Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.</p><p><strong>Om företaget</strong></p><p>Valcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.</p><p><strong>Om tjänsten</strong></p><p>Som Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.</p><p>I rollen som Data Engineer kommer du bland annat att arbeta med:</p><ul><li>Utveckling och underhåll av dataplattformar i Azure</li><li>Bygga och optimera ELT-pipelines för insamling och transformering av data</li><li>Arbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt</li><li>Datamodellering enligt stjärnmodellering och/eller medallion-arkitektur</li><li>Automatisering och deployment via Azure DevOps, CI/CD-pipelines</li><li>Infrastruktur som kod med Terraform, Bicep eller ARM</li><li>Utveckling i Python (Spark/Scala) och SQL</li><li>Integrationer via API:er</li><li>Versionshantering i Git</li></ul><p><strong>Vi söker dig som&nbsp;</strong></p><ul><li>har minst 3 års erfarenhet som Data Engineer eller liknande roll</li><li>Har god erfarenhet av Azure-miljön och-/eller AWS/GCP</li><li>Är van av att arbeta med moderna dataplattformar och datamodellering</li><li>Har goda kunskaper i Python och SQL</li><li>Har erfarenhet av CI/CD, Git och automatiserade deploymentflöden</li><li>Har förståelse för hela datakedjan – från datakälla till konsumtion</li></ul><p>Som person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.</p><p><strong>ÖVRIGT:</strong></p><p>Anställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.</p><p>I denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.</p><p>Har du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på<strong>&nbsp;</strong><strong>kristina@kraftsam.se</strong></p><p>Vi ser fram emot din ansökan!</p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5590649207',
#    'name': 'Kraftsam Rekrytering & Bemanning AB',
#    'workplace': 'Bricobomba'},
#   'application_details': {'information': None,
#    'reference': None,
#    'email': None,
#    'via_af': False,
#    'url': 'https://pnty-apply.ponty-system.se/kraftsam?id=2134&pnty_src=platsbanken',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#    'label': 'Dataingenjör',
#    'legacy_ams_taxonomy_id': '7338'},
#   'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#    'label': 'Ingenjörer och tekniker inom elektroteknik',
#    'legacy_ams_taxonomy_id': '3113'},
#   'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#    'label': 'Yrken med teknisk inriktning',
#    'legacy_ams_taxonomy_id': '18'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Stockholm',
#    'postcode': '11143',
#    'city': 'Stockholm',
#    'coordinates': [18.070462451025797, 59.33564974760078]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Stockholm',
#     'postcode': '11143',
#     'city': 'Stockholm',
#     'coordinates': [18.070462451025797, 59.33564974760078]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': 'Kristina Maksimovic',
#     'description': None,
#     'email': 'kristina@kraftsam.se',
#     'telephone': None,
#     'contact_type': 'Rekryterare'}],
#   'publication_date': '2026-09-07T08:36:21',
#   'last_publication_date': '2026-10-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_JOBPOSTING',
#   'timestamp': 1788762981859},
#  {'relevance': 1.0,
#   'id': '31117617',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31117617',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5593607517/logotyper/logo.png',
#   'headline': 'Data Engineer Stockholm Hybrid',
#   'application_deadline': '2026-11-28T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Om uppdraget 🚀\nVi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.\nI rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.\nHär värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.\nDina arbetsuppgifter 💻\nDesigna, utveckla och underhålla skalbara datapipelines\n\n\nBygga och vidareutveckla moderna dataplattformar\n\n\nSäkerställa hög datakvalitet, säkerhet och förvaltningsbarhet\n\n\nArbeta med Python, SQL och moderna dataverktyg\n\n\nImplementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar\n\n\nOmvandla verksamhetsbehov till robusta tekniska lösningar\n\n\nDelta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet\n\n\nUtforska och använda AI-verktyg för att effektivisera utvecklingsarbetet\n\nFörväntade leveranser 🎯\nSkalbara och robusta datapipelines\n\n\nDataplattformar med hög kvalitet och säkerhet\n\n\nVälstrukturerade dataflöden som stödjer verksamhetens behov\n\n\nHållbara tekniska lösningar med lång livslängd\n\n\nDokumenterad och förvaltningsbar kod\n\n\nAktivt bidrag till teknisk utveckling och kunskapsdelning\n\nDin profil ✅Obligatoriska kompetenser\nUniversitetsexamen inom teknik, datavetenskap eller motsvarande\n\n\nMinst 4–5 års erfarenhet som Data Engineer eller Backend Developer\n\n\nMycket goda kunskaper i Python\n\n\nMycket goda kunskaper i SQL\n\n\nErfarenhet av att utveckla och underhålla datapipelines\n\n\nErfarenhet av moderna dataplattformar\n\n\nFlytande svenska i tal och skrift\n\n\nFörmåga att arbeta hands-on i tekniska leveranser\n\nMeriterande färdigheter ⭐\nErfarenhet av Databricks\n\n\nErfarenhet av Microsoft Fabric\n\n\nErfarenhet av Apache Spark\n\n\nErfarenhet av dbt\n\n\nErfarenhet av Azure, AWS eller GCP\n\n\nErfarenhet av ETL- och ELT-processer\n\n\nErfarenhet av AI-verktyg och moderna utvecklingsverktyg\n\n\nKonsulterfarenhet\n\nPersonliga egenskaper 🤝\nVi tror att du är en person som:\n\nHar ett starkt kvalitetsfokus\n\n\nÄr tekniskt nyfiken och gillar att lära dig nytt\n\n\nKan kommunicera tekniska lösningar på ett tydligt sätt\n\n\nTrivs i samarbete med både kollegor och verksamhet\n\n\nHar förståelse för sambandet mellan teknik och affärsnytta\n\n\nÄr prestigelös och delar gärna med dig av din kunskap\n\nVi erbjuder 🎁\nFast månadslön\n\n\nSjukvårdsförsäkring\n\n\nPensionsavsättning\n\n\nFriskvårdsbidrag\n\n\nUtökad föräldrapenning\n\n\nMöjlighet att påverka din egen utveckling\n\n\nLångsiktiga och tekniskt intressanta uppdrag\n\n\nEn kultur präglad av samarbete, lärande och kvalitet\n\n\n📍 Plats: Stockholm (Hybrid)\n⏰ Omfattning: Heltid\n📅 Start: Omgående\n📌 Sista ansökningsdag: Urval sker löpande\nSway Sourcing är en innovativ rekryteringspartner som specialiserar sig på att matcha rätt talang med rätt företag – snabbt och effektivt. Vårt huvudfokus ligger inom Ekonomi, Administration, HR, Marknad och IT, men vi har även den breda expertis och flexibilitet som krävs för att leverera skräddarsydda rekryteringslösningar inom alla branscher.\nTrots att vi är en relativt ny aktör har vi redan byggt förtroende hos många av Sveriges största företag och arbetar både nationellt och internationellt. Med baser i Sverige och Spanien erbjuder vi en unik kombination av lokal expertis och global räckvidd. Vårt starka nätverk och djupa branschinsikter gör oss till en självklar partner för företag som vill ligga steget före i sin rekrytering.',
#    'text_formatted': '<strong>Om uppdraget 🚀</strong><p>Vi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.</p><p>I rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.</p><p>Här värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.</p><strong>Dina arbetsuppgifter 💻</strong><ul><li><p>Designa, utveckla och underhålla skalbara datapipelines</p></li><li><p>Bygga och vidareutveckla moderna dataplattformar</p></li><li><p>Säkerställa hög datakvalitet, säkerhet och förvaltningsbarhet</p></li><li><p>Arbeta med Python, SQL och moderna dataverktyg</p></li><li><p>Implementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar</p></li><li><p>Omvandla verksamhetsbehov till robusta tekniska lösningar</p></li><li><p>Delta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet</p></li><li><p>Utforska och använda AI-verktyg för att effektivisera utvecklingsarbetet</p></li></ul><strong>Förväntade leveranser 🎯</strong><ul><li><p>Skalbara och robusta datapipelines</p></li><li><p>Dataplattformar med hög kvalitet och säkerhet</p></li><li><p>Välstrukturerade dataflöden som stödjer verksamhetens behov</p></li><li><p>Hållbara tekniska lösningar med lång livslängd</p></li><li><p>Dokumenterad och förvaltningsbar kod</p></li><li><p>Aktivt bidrag till teknisk utveckling och kunskapsdelning</p></li></ul><strong>Din profil ✅</strong><strong>Obligatoriska kompetenser</strong><ul><li><p>Universitetsexamen inom teknik, datavetenskap eller motsvarande</p></li><li><p>Minst 4–5 års erfarenhet som Data Engineer eller Backend Developer</p></li><li><p>Mycket goda kunskaper i Python</p></li><li><p>Mycket goda kunskaper i SQL</p></li><li><p>Erfarenhet av att utveckla och underhålla datapipelines</p></li><li><p>Erfarenhet av moderna dataplattformar</p></li><li><p>Flytande svenska i tal och skrift</p></li><li><p>Förmåga att arbeta hands-on i tekniska leveranser</p></li></ul><strong>Meriterande färdigheter ⭐</strong><ul><li><p>Erfarenhet av Databricks</p></li><li><p>Erfarenhet av Microsoft Fabric</p></li><li><p>Erfarenhet av Apache Spark</p></li><li><p>Erfarenhet av dbt</p></li><li><p>Erfarenhet av Azure, AWS eller GCP</p></li><li><p>Erfarenhet av ETL- och ELT-processer</p></li><li><p>Erfarenhet av AI-verktyg och moderna utvecklingsverktyg</p></li><li><p>Konsulterfarenhet</p></li></ul><strong>Personliga egenskaper 🤝</strong><p>Vi tror att du är en person som:</p><ul><li><p>Har ett starkt kvalitetsfokus</p></li><li><p>Är tekniskt nyfiken och gillar att lära dig nytt</p></li><li><p>Kan kommunicera tekniska lösningar på ett tydligt sätt</p></li><li><p>Trivs i samarbete med både kollegor och verksamhet</p></li><li><p>Har förståelse för sambandet mellan teknik och affärsnytta</p></li><li><p>Är prestigelös och delar gärna med dig av din kunskap</p></li></ul><strong>Vi erbjuder 🎁</strong><ul><li><p>Fast månadslön</p></li><li><p>Sjukvårdsförsäkring</p></li><li><p>Pensionsavsättning</p></li><li><p>Friskvårdsbidrag</p></li><li><p>Utökad föräldrapenning</p></li><li><p>Möjlighet att påverka din egen utveckling</p></li><li><p>Långsiktiga och tekniskt intressanta uppdrag</p></li><li><p>En kultur präglad av samarbete, lärande och kvalitet</p></li></ul><p><strong>📍 Plats:</strong> Stockholm (Hybrid)</p><p><strong>⏰ Omfattning:</strong> Heltid</p><p><strong>📅 Start:</strong> Omgående</p><p><strong>📌 Sista ansökningsdag:</strong> Urval sker löpande</p><p>Sway Sourcing är en innovativ rekryteringspartner som specialiserar  ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'https://www.swaysourcing.com',
#    'organization_number': '5593607517',
#    'name': 'Sway Sourcing Sweden Aktiebolag',
#    'workplace': 'Sway Sourcing'},
#   'application_details': {'information': None,
#    'reference': 'teamtailor-7828036-2028375',
#    'email': None,
#    'via_af': False,
#    'url': 'https://www.swaysourcing.com/jobs/7828036-data-engineer-stockholm-hybrid/applications/new?promotion=2028375-arbetsformedlingen',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'fg7B_yov_smw',
#    'label': 'Systemutvecklare/Programmerare',
#    'legacy_ams_taxonomy_id': '2419'},
#   'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#    'label': 'Mjukvaru- och systemutvecklare m.fl.',
#    'legacy_ams_taxonomy_id': '2512'},
#   'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#    'label': 'Data/IT',
#    'legacy_ams_taxonomy_id': '3'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': '111 29',
#    'postcode': '11129',
#    'city': 'Stockholm',
#    'coordinates': [18.071134441016927, 59.324378835098074]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': '111 29',
#     'postcode': '11129',
#     'city': 'Stockholm',
#     'coordinates': [18.071134441016927, 59.324378835098074]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-06-01T13:24:58',
#   'last_publication_date': '2026-11-28T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_JOBPOSTING',
#   'timestamp': 1780313098640},
#  {'relevance': 1.0,
#   'id': '30990931',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30990931',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5568177124/logotyper/logo.png',
#   'headline': 'Data Engineer - Stockholm',
#   'application_deadline': '2026-10-31T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Arbetsuppgifter\n\nSom Data Engineer på Columbus kommer du att vara en del av ett team som levererar moderna Data & AI-lösningar till kunder inom olika branscher. Din roll fokuserar på att bygga skalbara och moderna dataplattformar – vilket möjliggör för avancerad analys\xa0till beslutsstöd.\nEn typisk arbetsdag kan innebära att du designar och bygger datapipelines i Azure Data Factory, arbetar med Datalake-arkitekturer i Microsoft Fabric eller utvecklar lösningar i plattformar som Databricks eller Snowflake. Du samarbetar med lösningsarkitekter och affärskonsulter för att leverera värdefulla lösningar för våra kunder.\nVi arbetar främst inom Microsofts teknologistack, och dina projekt kommer ofta att involvera tjänster som Azure Data Lake, Synapse Analytics, Power BI med mera. Erfarenhet av – eller nyfikenhet på – Microsoft Fabric är mycket meriterande, då många av våra kunder är på väg i den riktningen.\n\nSå här säger Kristin – Senior BI-konsult – om livet på Columbus: "En stor anledning till att jag började på Columbus var möjligheten att få arbeta både med projektleveranser och ny teknik. Jag uppskattar att vara en del av ett team som driver lösningar framåt tillsammans. Vi känner varandra väl och delar på ansvar och erfarenheter, vilket gör att vi snabbt kan anpassa oss och nå våra mål. Att arbeta med flera kunder samtidigt ger mig både trygghet inom de områden där jag är stark och möjligheten att växa genom nya utmaningar. För mig handlar projektleveranser om att skapa långsiktigt värde och hållbara lösningar som verkligen gör skillnad för kunden."\n\nVad vi önskar att du har med dig\nDu har ett par års praktisk erfarenhet av att bygga datapipelines och hantera dataflöden i molnmiljöer, gärna i Azure.\n\n\nDu är van att arbeta med både strukturerad och ostrukturerad data och har god förståelse för moderna data warehouse-koncept.\n\n\nDu har lätt för att samarbeta med både tekniska team och kundens\xa0representanter\n\n\nPlease note that this position requires fluency in English & Swedish and requires a Swedish working VISA/Citizenship.\nAnsökan och nästa steg\nHos oss ansöker du enkelt\xa0med din LinkedIn-profil eller CV, utan att behöva fylla i långa frågeformulär. Du behöver inte skicka in något personligt brev.\xa0\nI vår rekryteringsprocess använder vi logik- och personlighetstester. Vi tar alltid referenser och genomför en bakgrundskontroll innan anställning eller erbjudande ges. Intervjuer sker löpande.\xa0Vid frågor är du välkommen att kontakta ansvarig rekryterare Daniel Sparrow.\xa0\nOm Data & AI\nVilka är vi? Vi är ett team med BI-konsulter som levererar Data- och AI-projekt inom Business Intelligence, AI och Machine Learning. Vi samarbetar nära med konsulter från andra affärsområden – Dynamics, M3 och Digital Commerce.\nVarför? Vi vill hjälpa våra kunder att nå sina affärsmål och göra deras vardag mer effektiv! Målet är att säkerställa deras långsiktiga framgång och guida kunderna genom att vara deras Trusted Advisor. Vi samarbetar med kunderna för att optimera deras lösningar. 💫 \nJobba på Columbus\nColumbus är ett företag där värderingar står i centrum, där engagerade medarbetare stöttar varandra genom både toppar och dalar. Vi tror på balans mellan jobb och fritid – oavsett om det handlar om att lämna på förskola\xa0eller att ta emot ett paket "någon gång mellan 10 och 19".\xa0Hos oss finns tid för återhämtning, och vi arbetar proaktivt med fokus på framtiden. Vi vet också hur man firar framgångar, med allt från fika och lyxiga frukostar till after work på kontoret, och gör det gärna ofta!\xa0🥳 \nStay curious, Build trust, Collaborate, Deliver customer success - Vi vill hävda att våra värdeord gör mer nytta än att bara hänga snyggt på väggen! Dessa vägleder vårt arbete både internt och externt. Genom långsiktiga partnerskap med våra kunder, interna initiativ med Culture Ambassadors, kompetensutveckling inom affärsområdena till högkvalitativa lösningar till våra kunder.  \nVad and ...
#    'text_formatted': '<strong>Arbetsuppgifter</strong><p></p><p>Som Data Engineer på Columbus kommer du att vara en del av ett team som levererar moderna Data &amp; AI-lösningar till kunder inom olika branscher. Din roll fokuserar på att bygga skalbara och moderna dataplattformar – vilket möjliggör för avancerad analys\xa0till beslutsstöd.</p><p>En typisk arbetsdag kan innebära att du designar och bygger datapipelines i Azure Data Factory, arbetar med Datalake-arkitekturer i Microsoft Fabric eller utvecklar lösningar i plattformar som Databricks eller Snowflake. Du samarbetar med lösningsarkitekter och affärskonsulter för att leverera värdefulla lösningar för våra kunder.</p><p>Vi arbetar främst inom Microsofts teknologistack, och dina projekt kommer ofta att involvera tjänster som Azure Data Lake, Synapse Analytics, Power BI med mera. Erfarenhet av – eller nyfikenhet på – Microsoft Fabric är mycket meriterande, då många av våra kunder är på väg i den riktningen.</p><p></p><p><strong>Så här säger Kristin – Senior BI-konsult – om livet på Columbus:</strong> "En stor anledning till att jag började på Columbus var möjligheten att få arbeta både med projektleveranser och ny teknik. Jag uppskattar att vara en del av ett team som driver lösningar framåt tillsammans. Vi känner varandra väl och delar på ansvar och erfarenheter, vilket gör att vi snabbt kan anpassa oss och nå våra mål. Att arbeta med flera kunder samtidigt ger mig både trygghet inom de områden där jag är stark och möjligheten att växa genom nya utmaningar. För mig handlar projektleveranser om att skapa långsiktigt värde och hållbara lösningar som verkligen gör skillnad för kunden."</p><p></p><strong>Vad vi önskar att du har med dig</strong><ul><li><p>Du har ett par års praktisk erfarenhet av att bygga datapipelines och hantera dataflöden i molnmiljöer, gärna i Azure.</p></li><li><p>Du är van att arbeta med både strukturerad och ostrukturerad data och har god förståelse för moderna data warehouse-koncept.</p></li><li><p>Du har lätt för att samarbeta med både tekniska team och kundens\xa0representanter</p></li></ul><p><strong><em>Please note that this position requires fluency in English &amp; Swedish and requires a Swedish working VISA/Citizenship.</em></strong></p><strong>Ansökan och nästa steg</strong><p>Hos oss ansöker du enkelt\xa0med din LinkedIn-profil eller CV, utan att behöva fylla i långa frågeformulär. Du behöver inte skicka in något personligt brev.\xa0</p><p>I vår rekryteringsprocess använder vi logik- och personlighetstester. Vi tar alltid referenser och genomför en bakgrundskontroll innan anställning eller erbjudande ges. Intervjuer sker löpande.\xa0Vid frågor är du välkommen att kontakta ansvarig rekryterare Daniel Sparrow.\xa0</p><strong>Om Data &amp; AI</strong><p><strong>Vilka är vi? </strong>Vi är ett team med BI-konsulter som levererar Data- och AI-projekt inom Business Intelligence, AI och Machine Learning. Vi samarbetar nära med konsulter från andra affärsområden – Dynamics, M3 och Digital Commerce.</p><p><strong>Varför? </strong>Vi vill hjälpa våra kunder att nå sina affärsmål och göra deras vardag mer effektiv! Målet är att säkerställa deras långsiktiga framgång och guida kunderna genom att vara deras<em> Trusted Advisor</em>. Vi samarbetar med kunderna för att optimera deras lösningar. 💫<strong> </strong></p><strong>Jobba på Columbus</strong><p>Columbus är ett företag där värderingar står i centrum, där engagerade medarbetare stöttar varandra genom både toppar och dalar. Vi tror på balans mellan jobb och fritid – oavsett om det handlar om att lämna på förskola\xa0eller att ta emot ett paket "någon gång mellan 10 och 19".\xa0Hos oss finns tid för återhämtning, och vi arbetar proaktivt med fokus på framtiden. Vi vet också hur man firar framgångar, med allt från fika och lyxiga frukostar till after work på kontoret, och gör det gärna ofta!\xa0🥳 </p><p><strong>Stay curious, Build trust, Collaborate, Deliver customer success</strong> - Vi vill hävda  ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'asrX_9Df_ukn',
#    'label': 'Fast och rörlig lön',
#    'legacy_ams_taxonomy_id': '7'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'https://career.columbusglobal.com',
#    'organization_number': '5568177124',
#    'name': 'Columbus Sweden AB',
#    'workplace': 'Columbus Sweden, Poland, Germany & Czech Republic'},
#   'application_details': {'information': None,
#    'reference': 'teamtailor-7615684-1979836',
#    'email': None,
#    'via_af': False,
#    'url': 'https://career.columbusglobal.com/jobs/7615684-data-engineer-stockholm/applications/new?promotion=1979836-arbetsformedlingen',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'TT8h_qKk_1iu',
#    'label': 'Affärskonsult, IT',
#    'legacy_ams_taxonomy_id': '7579'},
#   'occupation_group': {'concept_id': 'UXKZ_3zZ_ipB',
#    'label': 'Systemanalytiker och IT-arkitekter m.fl.',
#    'legacy_ams_taxonomy_id': '2511'},
#   'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#    'label': 'Data/IT',
#    'legacy_ams_taxonomy_id': '3'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Drottninggatan 71D',
#    'postcode': '11136',
#    'city': 'Stockholm',
#    'coordinates': [18.0586425696733, 59.3365331584778]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Drottninggatan 71D',
#     'postcode': '11136',
#     'city': 'Stockholm',
#     'coordinates': [18.0586425696733, 59.3365331584778]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-05-04T15:46:48',
#   'last_publication_date': '2026-10-31T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_JOBPOSTING',
#   'timestamp': 1777902408632},
#  {'relevance': 0.9566538174996003,
#   'id': '30859146',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30859146',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590917851/logotyper/logo.png',
#   'headline': 'Data Engineer – Konsultuppdrag, Stockholm',
#   'application_deadline': '2026-09-29T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Om uppdraget\nVi förbereder just nu ett spännande konsultuppdrag där du som Data Engineer får möjlighet att ta ett helhetsgrepp kring en organisations datalandskap. Uppdraget handlar i grunden om att se till att rätt data når rätt personer i rätt tid – och att infrastrukturen bakom är robust, skalbar och väldokumenterad.\nDu kommer att arbeta i skärningspunkten mellan teknik och verksamhet: bygga och förfina datapipelines, ta fram beslutsunderlag genom visualisering, och vara den person teamet vänder sig till när det blir tekniskt komplext. Det här passar dig som trivs med att äga helheten snarare än att bara leverera enskilda komponenter.\nPlats: Stockholm (hybrid, 2–3 dagar på plats per vecka)  Start: Omgående  Omfattning: Heltid \n Det här jobbar du med i praktiken\nBygga, drifta och finjustera ett Snowflake-baserat datalager\n\n\nSkapa och vidareutveckla rapporter och dashboards i Power BI som verksamheten faktiskt använder\n\n\nDesigna och underhålla datapipelines med ETL/ELT-metoder\n\n\nKvalitetssäkra data och se till att hanteringen lever upp till GDPR och interna riktlinjer\n\n\nHålla dokumentationen levande – datamodeller, flöden och rapportlogik\n\n\nVara bryggan mellan IT-avdelning och affärssida\n\n\nCoacha och stötta kollegor i tekniska frågor\n\nDin profil\nDu har en stark teknisk grund och är van att jobba hands-on med data i hela kedjan – från källa till färdig rapport. Vi ser gärna att du har erfarenhet av:\n\nSnowflake – du har jobbat aktivt med plattformen, inte bara snuddat vid den\n\n\nPower BI – du bygger genomtänkta rapporter och förstår datamodellen bakom\n\n\nSQL – ditt starkaste verktyg i verktygslådan\n\n\nPython – för automation, transformation eller analys\n\n\nETL/ELT-verktyg – gärna dbt, men annan relevant erfarenhet fungerar också\n\n\nDu kommunicerar obehindrat på svenska och engelska och är den typen som tar initiativ, driver framåt och inte väntar på att bli tillsagd.\nBonuspoäng om du även har:\nErfarenhet av agilt arbetssätt och DevOps-tänk inom dataområdet\n\n\nPraktisk erfarenhet av datamodellering och prestandaoptimering i datalager\n\nLåter det som du?\nHör av dig med ditt CV så berättar vi mer. Uppdraget startar omgående och vi vill gärna ha dialog med relevanta kandidater så snart som möjligt.',
#    'text_formatted': '<strong>Om uppdraget</strong><p>Vi förbereder just nu ett spännande konsultuppdrag där du som Data Engineer får möjlighet att ta ett helhetsgrepp kring en organisations datalandskap. Uppdraget handlar i grunden om att se till att rätt data når rätt personer i rätt tid – och att infrastrukturen bakom är robust, skalbar och väldokumenterad.</p><p>Du kommer att arbeta i skärningspunkten mellan teknik och verksamhet: bygga och förfina datapipelines, ta fram beslutsunderlag genom visualisering, och vara den person teamet vänder sig till när det blir tekniskt komplext. Det här passar dig som trivs med att äga helheten snarare än att bara leverera enskilda komponenter.</p><p><strong>Plats:</strong> Stockholm (hybrid, 2–3 dagar på plats per vecka)  <strong>Start:</strong> Omgående  <strong>Omfattning:</strong> Heltid </p><strong> Det här jobbar du med i praktiken</strong><ul><li><p>Bygga, drifta och finjustera ett Snowflake-baserat datalager</p></li><li><p>Skapa och vidareutveckla rapporter och dashboards i Power BI som verksamheten faktiskt använder</p></li><li><p>Designa och underhålla datapipelines med ETL/ELT-metoder</p></li><li><p>Kvalitetssäkra data och se till att hanteringen lever upp till GDPR och interna riktlinjer</p></li><li><p>Hålla dokumentationen levande – datamodeller, flöden och rapportlogik</p></li><li><p>Vara bryggan mellan IT-avdelning och affärssida</p></li><li><p>Coacha och stötta kollegor i tekniska frågor</p></li></ul><strong>Din profil</strong><p>Du har en stark teknisk grund och är van att jobba hands-on med data i hela kedjan – från källa till färdig rapport. Vi ser gärna att du har erfarenhet av:</p><ul><li><p><strong>Snowflake</strong> – du har jobbat aktivt med plattformen, inte bara snuddat vid den</p></li><li><p><strong>Power BI</strong> – du bygger genomtänkta rapporter och förstår datamodellen bakom</p></li><li><p><strong>SQL</strong> – ditt starkaste verktyg i verktygslådan</p></li><li><p><strong>Python</strong> – för automation, transformation eller analys</p></li><li><p><strong>ETL/ELT-verktyg</strong> – gärna dbt, men annan relevant erfarenhet fungerar också</p></li></ul><p>Du kommunicerar obehindrat på <strong>svenska och engelska</strong> och är den typen som tar initiativ, driver framåt och inte väntar på att bli tillsagd.</p><strong><strong>Bonuspoäng om du även har:</strong></strong><ul><li><p>Erfarenhet av agilt arbetssätt och DevOps-tänk inom dataområdet</p></li><li><p>Praktisk erfarenhet av datamodellering och prestandaoptimering i datalager</p></li></ul><strong>Låter det som du?</strong><p>Hör av dig med ditt CV så berättar vi mer. Uppdraget startar omgående och vi vill gärna ha dialog med relevanta kandidater så snart som möjligt.</p><p></p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'https://jobb.liminity.se',
#    'organization_number': '5590917851',
#    'name': 'Liminity AB',
#    'workplace': 'Liminity AB'},
#   'application_details': {'information': None,
#    'reference': 'teamtailor-7508091-1927705',
#    'email': None,
#    'via_af': False,
#    'url': 'https://jobb.liminity.se/jobs/7508091-data-engineer-konsultuppdrag-stockholm/applications/new?promotion=1927705-arbetsformedlingen',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#    'label': 'Dataingenjör',
#    'legacy_ams_taxonomy_id': '7338'},
#   'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#    'label': 'Ingenjörer och tekniker inom elektroteknik',
#    'legacy_ams_taxonomy_id': '3113'},
#   'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#    'label': 'Yrken med teknisk inriktning',
#    'legacy_ams_taxonomy_id': '18'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Kungsholmsgatan 13A',
#    'postcode': '11227',
#    'city': 'Stockholm',
#    'coordinates': [18.048279652214, 59.3309166785629]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Kungsholmsgatan 13A',
#     'postcode': '11227',
#     'city': 'Stockholm',
#     'coordinates': [18.048279652214, 59.3309166785629]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-04-02T11:57:42',
#   'last_publication_date': '2026-09-29T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_JOBPOSTING',
#   'timestamp': 1775123862035},
#  {'relevance': 0.94911322649824,
#   'id': '31479661',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31479661',
#   'logo_url': None,
#   'headline': 'Data Engineer - Stockholm, Hybrid',
#   'application_deadline': '2026-10-15T23:59:59',
#   'number_of_vacancies': 2,
#   'description': {'text': "Company Description:\nThe Employer is a modern data consultancy Company focused on building long-term, high-quality data solutions that create real business value. In a world where AI can generate code in seconds, we believe that true impact comes from deep craftsmanship, strong data modeling, and a solid understanding of quality and security.\nWe are founded by experienced entrepreneurs, technical leaders, and sales professionals who know how to build sustainable teams and meaningful client partnerships. Our ambition is to shape the future of tech consulting by combining technical excellence with a human-centered culture.\n\n\nOur services / Product:\nWe design and build robust data platforms, pipelines, and architectures that enable organizations to turn data into actionable insights.\nOur work spans across modern data ecosystems, including cloud-based platforms, advanced data processing, and AI-supported workflows. We focus on scalable, maintainable, and secure solutions using technologies such as Python, SQL, Microsoft Fabric, Databricks, Apache Spark, and dbt.\n\n\nAbout us & our references:\nWe work closely with our clients to understand their real needs and deliver solutions that stand the test of time. Rather than chasing short-term projects, we focus on long-term value creation and strong partnerships.\nOur founders bring extensive experience from building successful companies and leading high-performing teams, ensuring that both our consultants and our clients are set up for success.\n\n\nOur team & Culture:\nWe believe that great technology is built by people who care.\nWe foster a culture where knowledge sharing is as natural as grabbing a coffee together. There is no room for unnecessary internal competition or sharp elbows. Instead, we focus on collaboration, curiosity, and continuous learning.\nYou will join a team that values both technical excellence and human connection, proving that the best tech companies can be both smart and kind.\n\n\nRequirement Profile:\nWe are looking for a Data Engineer with 5+ years of experience as a developer or in a related field, including minimum 3 years of Data Engineering, who wants to grow within the data domain and work with modern technologies in a meaningful way. You take ownership of the business understanding and of the customer project and relationship, making sure the technical work connects to real value for the client.\n\n\nJob Responsibilities:\n- Design, build, and maintain scalable data pipelines and data platforms\n- Ensure high data quality, security, and maintainability across solutions\n- Collaborate with clients to translate business needs into robust technical solutions\n- Act as a bridge between modern technologies and sustainable system design\n\n\nDaily Activities:\nYou work at assignments at our client's site.\n- Develop and optimize data pipelines using tools such as Python, SQL, and modern data platforms\n- Work with cloud and data processing technologies like Databricks, Microsoft Fabric, Spark, or dbt\n- Participate in client projects where you ensure long-term value and technical excellence\n- Explore and apply AI tools to enhance development workflows while maintaining high standards\n\n\nQualifications and Requirements:\n- A university degree in engineering, computer science, or a related field\n- 5+ years as a developer, with minimum 3 years in Data Engineering\n- Strong skills in Python and SQL\n- Experience with building data pipelines and working with modern data platforms\n- Familiarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus\n- Interest in AI and modern coding tools such as coding agents\n- Fluent in Swedish, both spoken and written.\n\n\nPersonal Attributes:\n- Quality-oriented mindset with a strong understanding that data quality is the foundation of all analytics and AI\n- Technically curious with a broad interest in data, systems, and new technologies\n- Able to critical ...
# ...
#    'text_formatted': '<p>TL;DR</p><p>→ You own the data layer, ingestion, transformation, and modeling that makes analytics, reporting and AI possible.</p><p>→ Consultant role across the Nordics, with clients spanning industries from financial services to manufacturing.</p><p>→ You work in cross functional delivery teams alongside Platform, Analytics and GenAI Developers, each owning a distinct layer of the stack.</p><p>→ Certifications without a debate. Colleagues who are obsessed with the craft. Freedom to grow your way.</p><p><br></p><p><strong>What you\'ll do</strong></p><p>As a Data Engineer, you’ll be building the data platforms that everything else depends on. From raw source systems to production-ready models consumed by analysts, ML pipelines, and business users. You own the path data takes to become useful. The work is hands-on Python and SQL, heavy on PySpark, and grounded in Kimball modeling and lakehouse architecture.</p><p>You come in before the solution is defined. Together with the client, you shape what gets built, then you build it. You\'ll work in cross-functional delivery teams alongside platform engineers and AI developers, each owning a distinct layer of the stack.</p><p><br></p><p>A few examples of what this looks like in practice:</p><ul><li>Building a Kafka-based ingestion framework for a major insurance group, onboarding several thousand tables at scale so multiple downstream teams can actually use the data they need.</li></ul><p><br></p><ul><li>Lifting an on-prem data warehouse into a cloud-based Databricks lakehouse for a Nordic logistics company, standing up CI/CD, integration, modeling, and quality assurance, then scaling for new use cases.</li></ul><p><br></p><ul><li>Auditing a manufacturing company\'s data platform against best practices, delivering a migration plan, then staying on to bring in new sources, optimize workflows, and build out analytics models.</li></ul><p><br></p><p>The bar for what "done" means here is high: production-grade, observable, secure and used.</p><p><br></p><p><strong>What you get</strong></p><p><strong>Assignments that accelerate you.</strong> Every 6–18 months you\'re in a new engagement. New industry, new architecture decisions, new stakeholders to earn trust from. You\'ll face more distinct technical challenges in two years here than most engineers see in five.</p><p><strong>Work that\'s hard to come by elsewhere.</strong> Modern data platforms underpinning enterprise AI is one of the most technically demanding spaces right now. The problems here aren\'t solved yet, and you\'ll be among the people solving them.</p><p><strong>Your direction, your call.</strong> Want to go deep technically, specialise in Databricks and Spark engineering, platform foundations or analytics engineering? Go for it. Want to grow toward Tech Lead or Solution Architect, steering delivery and building long-term client relationships? Also go for it. Both paths are real and equally valued.</p><p><strong>People who make you better.</strong> The people here are genuinely passionate about technology, not as a job, but as something they care about. Engineers who go deep because they want to, follow the space obsessively, and get restless when things stop moving. That\'s what keeps Redeploy consistently ahead, and it\'s what you\'ll feel from day one.</p><p><strong>The Perks.</strong> 30 days vacation · hybrid work and flexible hours · private medical insurance · pension (ITP1) · wellness allowance 5,000 SEK · free choice of tools and tech · free breakfast, soda and snacks · yearly gatherings and AW\'s · a team with genuine interests outside work — gaming, food, running, padel, golf, football, cycling</p><p><br></p><p><strong>Who you are</strong></p><p>You take ownership, hold yourself to a high standard, and bring real opinions to the table. You communicate clearly with both technical and non-technical stakeholders, and you\'re energised by the consulting pace, new challenges, new contexts, and th ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#    'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'asrX_9Df_ukn',
#    'label': 'Fast och rörlig lön',
#    'legacy_ams_taxonomy_id': '7'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'http://redeploy.com',
#    'organization_number': '5590055280',
#    'name': 'Redeploy AB',
#    'workplace': 'Redeploy AB'},
#   'application_details': {'information': None,
#    'reference': None,
#    'email': None,
#    'via_af': False,
#    'url': 'https://careers.redeploy.com/jobs/5095583-data-engineer',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#    'label': 'Dataingenjör',
#    'legacy_ams_taxonomy_id': '7338'},
#   'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#    'label': 'Ingenjörer och tekniker inom elektroteknik',
#    'legacy_ams_taxonomy_id': '3113'},
#   'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#    'label': 'Yrken med teknisk inriktning',
#    'legacy_ams_taxonomy_id': '18'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Torsgatan 4',
#    'postcode': '11361',
#    'city': 'Stockholm',
#    'coordinates': [18.044506816056344, 59.338577169215036]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Torsgatan 4',
#     'postcode': '11361',
#     'city': 'Stockholm',
#     'coordinates': [18.044506816056344, 59.338577169215036]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-04-20T10:45:10',
#   'last_publication_date': '2026-09-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1777556480755},
#  {'relevance': 0.47220161127348514,
#   'id': '30862433',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30862433',
#   'logo_url': None,
#   'headline': 'Data Engineer',
#   'application_deadline': '2026-09-29T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'About us At Techrytera AB, recruitment starts with you. We are a staffing and recruitment company with deep expertise and a clear focus on IT and Engineering. With our industry knowledge and close dialogue with both candidates and clients, we create precise matches where the right skills meet the right needs.\nWe believe that a truly great match is not just about a job description – it’s about your experience, your potential, and what you genuinely want to develop in. That’s why we always focus on the individual. By understanding your background, motivations, and ambitions, we can connect you with assignments and roles at our clients where you have the right conditions to grow and make an impact.\nOur goal is to build long-term and meaningful collaborations – for both you as a candidate and for our clients. \nJob Description We are looking for a Data Engineer or Backend Developer with a 4-5 years of experience or more senior who wants to grow within the data domain and work with modern technologies in a meaningful way.\nQualifications and Requirements:\nA degree in engineering, computer science, or a related field\n4-5 years of experience or more as a Data Engineer or Backend Developer\nStrong skills in Python and SQL\nExperience with building data pipelines and working with modern data platforms\nFamiliarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus\nInterest in AI and modern coding tools such as coding agents\nFluent in Swedish, both spoken and written.\nApplication\nWhen you apply through Techrytera AB, you’re not just applying for a job – you’re starting a dialogue about your career path. We want to get to know you, your experience, and your ambitions so that we can match you with the right opportunities at our clients.\nDoes this sound interesting? Submit your application or get in touch with us to learn more. We look forward to discovering the next step in your career together with you.',
#    'text_formatted': '<p><strong>About us</strong> At <strong>Techrytera AB</strong>, recruitment starts with you. We are a staffing and recruitment company with deep expertise and a clear focus on IT and Engineering. With our industry knowledge and close dialogue with both candidates and clients, we create precise matches where the right skills meet the right needs.</p><p>We believe that a truly great match is not just about a job description – it’s about your experience, your potential, and what you genuinely want to develop in. That’s why we always focus on the individual. By understanding your background, motivations, and ambitions, we can connect you with assignments and roles at our clients where you have the right conditions to grow and make an impact.</p><p>Our goal is to build long-term and meaningful collaborations – for both you as a candidate and for our clients. </p><p><strong>Job Description</strong> We are looking for a Data Engineer or Backend Developer with a 4-5 years of experience or more senior who wants to grow within the data domain and work with modern technologies in a meaningful way.</p><p><strong>Qualifications and Requirements:</strong></p><p>A degree in engineering, computer science, or a related field</p><p>4-5 years of experience or more as a Data Engineer or Backend Developer</p><p>Strong skills in Python and SQL</p><p>Experience with building data pipelines and working with modern data platforms</p><p>Familiarity with tools such as Databricks, Microsoft Fabric, Apache Spark, or dbt is a plus</p><p>Interest in AI and modern coding tools such as coding agents</p><p>Fluent in Swedish, both spoken and written.</p><p><strong>Application</strong></p><p>When you apply through <strong>Techrytera AB</strong>, you’re not just applying for a job – you’re starting a dialogue about your career path. We want to get to know you, your experience, and your ambitions so that we can match you with the right opportunities at our clients.</p><p>Does this sound interesting? Submit your application or get in touch with us to learn more. We look forward to discovering the next step in your career together with you.</p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'https://www.techrytera.se',
#    'organization_number': '5595683623',
#    'name': 'Techrytera AB',
#    'workplace': 'Techrytera AB'},
#   'application_details': {'information': None,
#    'reference': 'teamtailor-7511135-1928800',
#    'email': None,
#    'via_af': False,
#    'url': 'https://www.techrytera.se/jobs/7511135-data-engineer/applications/new?promotion=1928800-arbetsformedlingen',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#    'label': 'Dataingenjör',
#    'legacy_ams_taxonomy_id': '7338'},
#   'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#    'label': 'Ingenjörer och tekniker inom elektroteknik',
#    'legacy_ams_taxonomy_id': '3113'},
#   'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#    'label': 'Yrken med teknisk inriktning',
#    'legacy_ams_taxonomy_id': '18'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Sveavägen 137',
#    'postcode': '11346',
#    'city': 'Stockholm',
#    'coordinates': [18.0503914327707, 59.3491119760471]},
#   'workplace_addresses': [{'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Sveavägen 137',
#     'postcode': '11346',
#     'city': 'Stockholm',
#     'coordinates': [18.0503914327707, 59.3491119760471]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-04-02T16:34:47',
#   'last_publication_date': '2026-09-29T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_JOBPOSTING',
#   'timestamp': 1775140487436}]

# %%
json_response.get("hits")[0]
# Out:
# {'relevance': 1.0,
#  'id': '31443496',
#  'external_id': None,
#  'original_id': None,
#  'label': [],
#  'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31443496',
#  'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5590649207/logotyper/logo.png',
#  'headline': 'Data Engineer - Stockholm',
#  'application_deadline': '2026-10-30T23:59:59',
#  'number_of_vacancies': 1,
#  'description': {'text': 'Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.\nOm företaget\nValcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.\nOm tjänsten\nSom Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.\nI rollen som Data Engineer kommer du bland annat att arbeta med:\nUtveckling och underhåll av dataplattformar i Azure\nBygga och optimera ELT-pipelines för insamling och transformering av data\nArbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt\nDatamodellering enligt stjärnmodellering och/eller medallion-arkitektur\nAutomatisering och deployment via Azure DevOps, CI/CD-pipelines\nInfrastruktur som kod med Terraform, Bicep eller ARM\nUtveckling i Python (Spark/Scala) och SQL\nIntegrationer via API:er\nVersionshantering i Git\n\nVi söker dig som\xa0\nhar minst 3 års erfarenhet som Data Engineer eller liknande roll\nHar god erfarenhet av Azure-miljön och-/eller AWS/GCP\nÄr van av att arbeta med moderna dataplattformar och datamodellering\nHar goda kunskaper i Python och SQL\nHar erfarenhet av CI/CD, Git och automatiserade deploymentflöden\nHar förståelse för hela datakedjan – från datakälla till konsumtion\n\nSom person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.\nÖVRIGT:\nAnställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.\nI denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.\nHar du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på\xa0kristina@kraftsam.se\nVi ser fram emot din ansökan!',
#   'text_formatted': '<p>Har du några års erfarenhet som Data Engineer och vill arbeta med moderna dataplattformar hos ett specialistbolag inom data? Då kan detta vara nästa steg för dig.</p><p><strong>Om företaget</strong></p><p>Valcon är ett stort konsultbolag med djup kompetens inom data och analytics. De arbetar med hela datakedjan – från infrastruktur och dataplattformar till analys, rapportering och maskininlärning och hjälper sina kunder att skapa verkligt affärsvärde med data.</p><p><strong>Om tjänsten</strong></p><p>Som Data Engineer hos Valcon kommer du att arbeta med design, utveckling och förvaltning av dataplattformar och datalösningar hos deras kunder. Du blir en viktig del i att bygga stabila och skalbara lösningar som möjliggör analys, rapportering och avancerad dataanvändning.</p><p>I rollen som Data Engineer kommer du bland annat att arbeta med:</p><ul><li>Utveckling och underhåll av dataplattformar i Azure</li><li>Bygga och optimera ELT-pipelines för insamling och transformering av data</li><li>Arbeta med data warehouse/lakehouse-lösningar såsom Snowflake, Databricks, Synapse/Fabric och dbt</li><li>Datamodellering enligt stjärnmodellering och/eller medallion-arkitektur</li><li>Automatisering och deployment via Azure DevOps, CI/CD-pipelines</li><li>Infrastruktur som kod med Terraform, Bicep eller ARM</li><li>Utveckling i Python (Spark/Scala) och SQL</li><li>Integrationer via API:er</li><li>Versionshantering i Git</li></ul><p><strong>Vi söker dig som&nbsp;</strong></p><ul><li>har minst 3 års erfarenhet som Data Engineer eller liknande roll</li><li>Har god erfarenhet av Azure-miljön och-/eller AWS/GCP</li><li>Är van av att arbeta med moderna dataplattformar och datamodellering</li><li>Har goda kunskaper i Python och SQL</li><li>Har erfarenhet av CI/CD, Git och automatiserade deploymentflöden</li><li>Har förståelse för hela datakedjan – från datakälla till konsumtion</li></ul><p>Som person är du kommunikativ, ödmjuk och pragmatisk. Du trivs i konsultrollen och har lätt för att samarbeta med både kollegor och kunder.</p><p><strong>ÖVRIGT:</strong></p><p>Anställningen är på heltid med en inledande provanställning på sex månader. Lön och tillträde sker enligt överenskommelse. Tjänsten är placerad i Stockholm.</p><p>I denna rekrytering samarbetar Valcon med Kraftsam Rekrytering och Bemanning. Externa rekryteringsbolag och säljare undanbedes vänligen men bestämt.</p><p>Har du frågor om tjänsten, vänligen kontakta ansvarig rekryterare Kristina Maksimovic på<strong>&nbsp;</strong><strong>kristina@kraftsam.se</strong></p><p>Vi ser fram emot din ansökan!</p>',
#   'company_information': None,
#   'needs': None,
#   'requirements': None,
#   'conditions': None},
#  'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#   'label': 'Vanlig anställning',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#   'label': 'Fast månads- vecko- eller timlön',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_description': None,
#  'duration': {'concept_id': 'a7uU_j21_mkL',
#   'label': 'Tills vidare',
#   'legacy_ams_taxonomy_id': '1'},
#  'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#   'label': 'Heltid',
#   'legacy_ams_taxonomy_id': '1'},
#  'scope_of_work': {'min': 100, 'max': 100},
#  'access': None,
#  'employer': {'phone_number': None,
#   'email': None,
#   'url': None,
#   'organization_number': '5590649207',
#   'name': 'Kraftsam Rekrytering & Bemanning AB',
#   'workplace': 'Bricobomba'},
#  'application_details': {'information': None,
#   'reference': None,
#   'email': None,
#   'via_af': False,
#   'url': 'https://pnty-apply.ponty-system.se/kraftsam?id=2134&pnty_src=platsbanken',
#   'other': None},
#  'experience_required': True,
#  'access_to_own_car': False,
#  'driving_license_required': False,
#  'driving_license': None,
#  'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#   'label': 'Dataingenjör',
#   'legacy_ams_taxonomy_id': '7338'},
#  'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#   'label': 'Ingenjörer och tekniker inom elektroteknik',
#   'legacy_ams_taxonomy_id': '3113'},
#  'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#   'label': 'Yrken med teknisk inriktning',
#   'legacy_ams_taxonomy_id': '18'},
#  'workplace_model': {'concept_id': 'ZxwM_gtz_n61', 'label': 'Arbete på plats'},
#  'workplace_address': {'municipality': 'Stockholm',
#   'municipality_code': '0180',
#   'municipality_concept_id': 'AvNB_uwa_6n6',
#   'region': 'Stockholms län',
#   'region_code': '01',
#   'region_concept_id': 'CifL_Rzy_Mku',
#   'country': 'Sverige',
#   'country_code': '199',
#   'country_concept_id': 'i46j_HmG_v64',
#   'street_address': 'Stockholm',
#   'postcode': '11143',
#   'city': 'Stockholm',
#   'coordinates': [18.070462451025797, 59.33564974760078]},
#  'workplace_addresses': [{'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Stockholm',
#    'postcode': '11143',
#    'city': 'Stockholm',
#    'coordinates': [18.070462451025797, 59.33564974760078]}],
#  'must_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'nice_to_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'application_contacts': [{'name': 'Kristina Maksimovic',
#    'description': None,
#    'email': 'kristina@kraftsam.se',
#    'telephone': None,
#    'contact_type': 'Rekryterare'}],
#  'publication_date': '2026-09-07T08:36:21',
#  'last_publication_date': '2026-10-30T23:59:59',
#  'removed': False,
#  'removed_date': None,
#  'source_type': 'VIA_JOBPOSTING',
#  'timestamp': 1788762981859}

# %%
json_response.get("hits")[1]
# Out:
# {'relevance': 1.0,
#  'id': '31117617',
#  'external_id': None,
#  'original_id': None,
#  'label': [],
#  'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31117617',
#  'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5593607517/logotyper/logo.png',
#  'headline': 'Data Engineer Stockholm Hybrid',
#  'application_deadline': '2026-11-28T23:59:59',
#  'number_of_vacancies': 1,
#  'description': {'text': 'Om uppdraget 🚀\nVi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.\nI rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.\nHär värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.\nDina arbetsuppgifter 💻\nDesigna, utveckla och underhålla skalbara datapipelines\n\n\nBygga och vidareutveckla moderna dataplattformar\n\n\nSäkerställa hög datakvalitet, säkerhet och förvaltningsbarhet\n\n\nArbeta med Python, SQL och moderna dataverktyg\n\n\nImplementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar\n\n\nOmvandla verksamhetsbehov till robusta tekniska lösningar\n\n\nDelta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet\n\n\nUtforska och använda AI-verktyg för att effektivisera utvecklingsarbetet\n\nFörväntade leveranser 🎯\nSkalbara och robusta datapipelines\n\n\nDataplattformar med hög kvalitet och säkerhet\n\n\nVälstrukturerade dataflöden som stödjer verksamhetens behov\n\n\nHållbara tekniska lösningar med lång livslängd\n\n\nDokumenterad och förvaltningsbar kod\n\n\nAktivt bidrag till teknisk utveckling och kunskapsdelning\n\nDin profil ✅Obligatoriska kompetenser\nUniversitetsexamen inom teknik, datavetenskap eller motsvarande\n\n\nMinst 4–5 års erfarenhet som Data Engineer eller Backend Developer\n\n\nMycket goda kunskaper i Python\n\n\nMycket goda kunskaper i SQL\n\n\nErfarenhet av att utveckla och underhålla datapipelines\n\n\nErfarenhet av moderna dataplattformar\n\n\nFlytande svenska i tal och skrift\n\n\nFörmåga att arbeta hands-on i tekniska leveranser\n\nMeriterande färdigheter ⭐\nErfarenhet av Databricks\n\n\nErfarenhet av Microsoft Fabric\n\n\nErfarenhet av Apache Spark\n\n\nErfarenhet av dbt\n\n\nErfarenhet av Azure, AWS eller GCP\n\n\nErfarenhet av ETL- och ELT-processer\n\n\nErfarenhet av AI-verktyg och moderna utvecklingsverktyg\n\n\nKonsulterfarenhet\n\nPersonliga egenskaper 🤝\nVi tror att du är en person som:\n\nHar ett starkt kvalitetsfokus\n\n\nÄr tekniskt nyfiken och gillar att lära dig nytt\n\n\nKan kommunicera tekniska lösningar på ett tydligt sätt\n\n\nTrivs i samarbete med både kollegor och verksamhet\n\n\nHar förståelse för sambandet mellan teknik och affärsnytta\n\n\nÄr prestigelös och delar gärna med dig av din kunskap\n\nVi erbjuder 🎁\nFast månadslön\n\n\nSjukvårdsförsäkring\n\n\nPensionsavsättning\n\n\nFriskvårdsbidrag\n\n\nUtökad föräldrapenning\n\n\nMöjlighet att påverka din egen utveckling\n\n\nLångsiktiga och tekniskt intressanta uppdrag\n\n\nEn kultur präglad av samarbete, lärande och kvalitet\n\n\n📍 Plats: Stockholm (Hybrid)\n⏰ Omfattning: Heltid\n📅 Start: Omgående\n📌 Sista ansökningsdag: Urval sker löpande\nSway Sourcing är en innovativ rekryteringspartner som specialiserar sig på att matcha rätt talang med rätt företag – snabbt och effektivt. Vårt huvudfokus ligger inom Ekonomi, Administration, HR, Marknad och IT, men vi har även den breda expertis och flexibilitet som krävs för att leverera skräddarsydda rekryteringslösningar inom alla branscher.\nTrots att vi är en relativt ny aktör har vi redan byggt förtroende hos många av Sveriges största företag och arbetar både nationellt och internationellt. Med baser i Sverige och Spanien erbjuder vi en unik kombination av lokal expertis och global räckvidd. Vårt starka nätverk och djupa branschinsikter gör oss till en självklar partner för företag som vill ligga steget före i sin rekrytering.',
#   'text_formatted': '<strong>Om uppdraget 🚀</strong><p>Vi söker en erfaren Data Engineer eller Backend Developer som vill arbeta med moderna dataplattformar, skalbara datapipelines och hållbara tekniska lösningar.</p><p>I rollen får du kombinera tekniskt djup med affärsförståelse och arbeta nära verksamheter för att omsätta behov till robusta data- och integrationslösningar. Du blir en del av en miljö där kvalitet, kunskapsdelning och teknisk utveckling står i centrum.</p><p>Här värdesätts tekniskt hantverk, långsiktigt tänkande och förmågan att skapa lösningar som håller över tid. Du får möjlighet att arbeta med moderna tekniker inom data engineering, cloud och AI-stödda utvecklingsprocesser samtidigt som du utvecklas tillsammans med erfarna kollegor.</p><strong>Dina arbetsuppgifter 💻</strong><ul><li><p>Designa, utveckla och underhålla skalbara datapipelines</p></li><li><p>Bygga och vidareutveckla moderna dataplattformar</p></li><li><p>Säkerställa hög datakvalitet, säkerhet och förvaltningsbarhet</p></li><li><p>Arbeta med Python, SQL och moderna dataverktyg</p></li><li><p>Implementera lösningar inom Databricks, Microsoft Fabric, Apache Spark och liknande plattformar</p></li><li><p>Omvandla verksamhetsbehov till robusta tekniska lösningar</p></li><li><p>Delta i tekniska diskussioner kring arkitektur, kvalitet och långsiktighet</p></li><li><p>Utforska och använda AI-verktyg för att effektivisera utvecklingsarbetet</p></li></ul><strong>Förväntade leveranser 🎯</strong><ul><li><p>Skalbara och robusta datapipelines</p></li><li><p>Dataplattformar med hög kvalitet och säkerhet</p></li><li><p>Välstrukturerade dataflöden som stödjer verksamhetens behov</p></li><li><p>Hållbara tekniska lösningar med lång livslängd</p></li><li><p>Dokumenterad och förvaltningsbar kod</p></li><li><p>Aktivt bidrag till teknisk utveckling och kunskapsdelning</p></li></ul><strong>Din profil ✅</strong><strong>Obligatoriska kompetenser</strong><ul><li><p>Universitetsexamen inom teknik, datavetenskap eller motsvarande</p></li><li><p>Minst 4–5 års erfarenhet som Data Engineer eller Backend Developer</p></li><li><p>Mycket goda kunskaper i Python</p></li><li><p>Mycket goda kunskaper i SQL</p></li><li><p>Erfarenhet av att utveckla och underhålla datapipelines</p></li><li><p>Erfarenhet av moderna dataplattformar</p></li><li><p>Flytande svenska i tal och skrift</p></li><li><p>Förmåga att arbeta hands-on i tekniska leveranser</p></li></ul><strong>Meriterande färdigheter ⭐</strong><ul><li><p>Erfarenhet av Databricks</p></li><li><p>Erfarenhet av Microsoft Fabric</p></li><li><p>Erfarenhet av Apache Spark</p></li><li><p>Erfarenhet av dbt</p></li><li><p>Erfarenhet av Azure, AWS eller GCP</p></li><li><p>Erfarenhet av ETL- och ELT-processer</p></li><li><p>Erfarenhet av AI-verktyg och moderna utvecklingsverktyg</p></li><li><p>Konsulterfarenhet</p></li></ul><strong>Personliga egenskaper 🤝</strong><p>Vi tror att du är en person som:</p><ul><li><p>Har ett starkt kvalitetsfokus</p></li><li><p>Är tekniskt nyfiken och gillar att lära dig nytt</p></li><li><p>Kan kommunicera tekniska lösningar på ett tydligt sätt</p></li><li><p>Trivs i samarbete med både kollegor och verksamhet</p></li><li><p>Har förståelse för sambandet mellan teknik och affärsnytta</p></li><li><p>Är prestigelös och delar gärna med dig av din kunskap</p></li></ul><strong>Vi erbjuder 🎁</strong><ul><li><p>Fast månadslön</p></li><li><p>Sjukvårdsförsäkring</p></li><li><p>Pensionsavsättning</p></li><li><p>Friskvårdsbidrag</p></li><li><p>Utökad föräldrapenning</p></li><li><p>Möjlighet att påverka din egen utveckling</p></li><li><p>Långsiktiga och tekniskt intressanta uppdrag</p></li><li><p>En kultur präglad av samarbete, lärande och kvalitet</p></li></ul><p><strong>📍 Plats:</strong> Stockholm (Hybrid)</p><p><strong>⏰ Omfattning:</strong> Heltid</p><p><strong>📅 Start:</strong> Omgående</p><p><strong>📌 Sista ansökningsdag:</strong> Urval sker löpande</p><p>Sway Sourcing är en innovativ rekryteringspartner som specialiserar s ...
#   'company_information': None,
#   'needs': None,
#   'requirements': None,
#   'conditions': None},
#  'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#   'label': 'Vanlig anställning',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#   'label': 'Fast månads- vecko- eller timlön',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_description': None,
#  'duration': {'concept_id': 'a7uU_j21_mkL',
#   'label': 'Tills vidare',
#   'legacy_ams_taxonomy_id': '1'},
#  'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#   'label': 'Heltid',
#   'legacy_ams_taxonomy_id': '1'},
#  'scope_of_work': {'min': 100, 'max': 100},
#  'access': None,
#  'employer': {'phone_number': None,
#   'email': None,
#   'url': 'https://www.swaysourcing.com',
#   'organization_number': '5593607517',
#   'name': 'Sway Sourcing Sweden Aktiebolag',
#   'workplace': 'Sway Sourcing'},
#  'application_details': {'information': None,
#   'reference': 'teamtailor-7828036-2028375',
#   'email': None,
#   'via_af': False,
#   'url': 'https://www.swaysourcing.com/jobs/7828036-data-engineer-stockholm-hybrid/applications/new?promotion=2028375-arbetsformedlingen',
#   'other': None},
#  'experience_required': True,
#  'access_to_own_car': False,
#  'driving_license_required': False,
#  'driving_license': None,
#  'occupation': {'concept_id': 'fg7B_yov_smw',
#   'label': 'Systemutvecklare/Programmerare',
#   'legacy_ams_taxonomy_id': '2419'},
#  'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#   'label': 'Mjukvaru- och systemutvecklare m.fl.',
#   'legacy_ams_taxonomy_id': '2512'},
#  'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#   'label': 'Data/IT',
#   'legacy_ams_taxonomy_id': '3'},
#  'workplace_model': {'concept_id': 'ZxwM_gtz_n61', 'label': 'Arbete på plats'},
#  'workplace_address': {'municipality': 'Stockholm',
#   'municipality_code': '0180',
#   'municipality_concept_id': 'AvNB_uwa_6n6',
#   'region': 'Stockholms län',
#   'region_code': '01',
#   'region_concept_id': 'CifL_Rzy_Mku',
#   'country': 'Sverige',
#   'country_code': '199',
#   'country_concept_id': 'i46j_HmG_v64',
#   'street_address': '111 29',
#   'postcode': '11129',
#   'city': 'Stockholm',
#   'coordinates': [18.071134441016927, 59.324378835098074]},
#  'workplace_addresses': [{'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': '111 29',
#    'postcode': '11129',
#    'city': 'Stockholm',
#    'coordinates': [18.071134441016927, 59.324378835098074]}],
#  'must_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'nice_to_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'application_contacts': [],
#  'publication_date': '2026-06-01T13:24:58',
#  'last_publication_date': '2026-11-28T23:59:59',
#  'removed': False,
#  'removed_date': None,
#  'source_type': 'VIA_JOBPOSTING',
#  'timestamp': 1780313098640}

# %%
json_response["hits"][-1]["headline"]
# Out:
# 'Data Engineer'

# %%
json_response["hits"][-1]["headline"], json_response["hits"][-1]["employer"]["name"]
# Out:
# ('Data Engineer', 'Techrytera AB')
